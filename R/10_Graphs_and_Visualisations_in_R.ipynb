# %% [markdown]
# #Plot()

# %% [markdown]
# * * *
#
# ###Plot()
#
#
# The `plot()` function is used to draw points (markers) in a diagram.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 specifies points on the **x-axis**.
#
# Parameter 2 specifies points on the **y-axis**.
#
# At its simplest, you can use the `plot()` function to plot two numbers against each other:
#
# ### Example
#
# ```r
# # Create a simple scatter plot with a single point at coordinates (1, 3)
# plot(1, 3)
# ```
#
# 1. **Creating a Scatter Plot:**
#    - The `plot()` function is used to create a scatter plot.
#    - In this case, we provide the x-coordinate as `1` and the y-coordinate as `3`.
#    - The result will be a scatter plot with a single point at the specified position.
#
# 2. **Result:**
#    - The plot will display a single point at coordinates (1, 3).
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_plot_simple.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_plot_simple)

# %%
# Draw one point in the diagram, at position 1 and 3
plot(1, 3)
# Out:
# plot without title

# %% [markdown]
# To draw more points, use [vectors](https://www.w3schools.com/r/r_vectors.asp):
#
# ### Example
#
# Draw two points in the diagram, one at position (1, 3) and one in position (8, 10):
#
#
# ```r
# # Create a scatter plot with two points
# # The first point has coordinates (1, 3)
# # The second point has coordinates (8, 10)
# plot(c(1, 8), c(3, 10))
# ```
#
# 1. **Creating a Scatter Plot:**
#    - The `plot()` function is used to create a scatter plot.
#    - We provide two vectors as arguments:
#      - The first vector contains the x-coordinates of the points: `c(1, 8)`.
#      - The second vector contains the y-coordinates of the points: `c(3, 10)`.
#
# 2. **Result:**
#    - The plot will display two points:
#      - Point 1: Coordinates (1, 3)
#      - Point 2: Coordinates (8, 10)
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_plot1.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_plot)
#
# * * *
#
# * * *

# %%
# Create a scatter plot with two points
# The first point has coordinates (1, 3)
# The second point has coordinates (8, 10)
plot(c(1, 8), c(3, 10))
# Out:
# plot without title

# %% [markdown]
# ##Multiple Points
#
#
# You can plot as many points as you like, just make sure you have the same number of points in both axis:
#
#
#
# ### Example
#
#
#
# ```r
# # Create a scatter plot with two points
# # The first point has coordinates (1, 3)
# # The second point has coordinates (2, 7)
# # The third point has coordinates (3, 8)
# # The fourth point has coordinates (4, 9)
# # The fifth point has coordinates (5, 12)
# plot(c(1, 2, 3, 4, 5), c(3, 7, 8, 9, 12))
#
# ```
#
# 1. **Creating a Scatter Plot:**
#    - The `plot()` function is used to create a scatter plot.
#    - We provide two vectors as arguments:
#      - The first vector contains the x-coordinates of the points: `c(1, 2, 3, 4, 5)`.
#      - The second vector contains the y-coordinates of the points: `c(3, 7, 8, 9, 12)`.
#
# 2. **Result (Expected Plot):**
#    - The plot would display five points on the graph.
#    - Each point corresponds to the pair of coordinates (x, y):
#      - Point 1: (1, 3)
#      - Point 2: (2, 7)
#      - Point 3: (3, 8)
#      - Point 4: (4, 9)
#      - Point 5: (5, 12)
#
# The resulting scatter plot would show these five data points, illustrating their positions in the coordinate system. 📊👍
#
#
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_plot2.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_plot3)
#
# * * *

# %%
# Create a scatter plot with two points
# The first point has coordinates (1, 3)
# The second point has coordinates (2, 7)
# The third point has coordinates (3, 8)
# The fourth point has coordinates (4, 9)
# The fifth point has coordinates (5, 12)
plot(c(1, 2, 3, 4, 5), c(3, 7, 8, 9, 12))
# Out:
# plot without title

# %% [markdown]
# For better organization, when you have many values, it is better to use variables:

# %%
x <- c(1, 2, 3, 4, 5)
y <- c(3, 7, 8, 9, 12)

plot(x, y)
# Out:
# plot without title

# %% [markdown]
# ##Sequences of Points
#
#
# If you want to draw dots in a sequence, on both the **x-axis** and the **y-axis**, use the `:` operator:
#
#
# ```r
# # Create a scatter plot with x-coordinates ranging from 1 to 10
# plot(1:10)
# ```
#
# 1. **Creating a Scatter Plot:**
#    - The `plot()` function is used to create a scatter plot.
#    - In this case, we provide a single argument: `1:10`.
#    - The `1:10` expression generates a sequence of integers from 1 to 10.
#
# 2. **Result (Expected Plot):**
#    - The plot will display points on the graph corresponding to the x-coordinates from 1 to 10.
#    - Since we only provide the x-coordinates, the y-coordinates are implicitly assumed to be the same as the x-coordinates (i.e., y = x).
#
# The resulting scatter plot would show points at positions (1, 1), (2, 2), ..., (10, 10). 📊👍
#
#
# * * *

# %%
# Create a scatter plot with x-coordinates ranging from 1 to 10
plot(1:10)
# Out:
# plot without title

# %% [markdown]
# ##Draw a Line
#
#
# The `plot()` function also takes a `type` parameter with the value `l` to draw a line to connect all the points in the diagram:
#
# ```r
# # Create a line plot with x-coordinates ranging from 1 to 10
# # The 'type' parameter is set to "l" to indicate a line plot
# plot(1:10, type="l")
# ```
#
# 1. **Creating a Line Plot:**
#    - The `plot()` function is used to create a line plot.
#    - We provide a single argument: `1:10`.
#    - The `1:10` expression generates a sequence of integers from 1 to 10.
#
# 2. **Line Plot (Expected Result):**
#    - The plot will display a line connecting the points corresponding to the x-coordinates from 1 to 10.
#    - Since we only provide the x-coordinates, the y-coordinates are implicitly assumed to be the same as the x-coordinates (i.e., y = x).
#
# The resulting line plot would show a straight line connecting the points (1, 1), (2, 2), ..., (10, 10). 📊👍
#
#
#
# * * *

# %%
# Create a line plot with x-coordinates ranging from 1 to 10
# The 'type' parameter is set to "l" to indicate a line plot
plot(1:10, type="l")
# Out:
# plot without title

# %% [markdown]
# ##Plot Labels
#
#
# The `plot()` function also accept other parameters, such as `main`, `xlab` and `ylab` if you want to customize the graph with a main title and different labels for the x and y-axis:
#
# ### Example
#
#
# ```r
# # Create a scatter plot with x-coordinates ranging from 1 to 10
# # Customize the plot title, x-axis label, and y-axis label
# plot(1:10, main="My Graph", xlab="The x-axis", ylab="The y axis")
# ```
#
# 1. **Creating a Scatter Plot:**
#    - The `plot()` function is used to create a scatter plot.
#    - We provide a single argument: `1:10`.
#    - The `1:10` expression generates a sequence of integers from 1 to 10.
#
# 2. **Customizing the Plot:**
#    - The `main` parameter specifies the title of the plot. In this case, it is set to "My Graph."
#    - The `xlab` parameter sets the label for the x-axis. Here, it is "The x-axis."
#    - The `ylab` parameter sets the label for the y-axis. Here, it is "The y axis."
#
# The resulting scatter plot would show points along the x-axis from 1 to 10, with the specified title and axis labels. 📊👍
#
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_plot_labels.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_plot_labels)
#
# * * *

# %%
# Create a scatter plot with x-coordinates ranging from 1 to 10
# Customize the plot title, x-axis label, and y-axis label
plot(1:10, main="My Graph", xlab="The x-axis", ylab="The y axis")
# Out:
# Plot with title “My Graph”

# %% [markdown]
# ## Graph Appearance
#
#
# There are many other parameters you can use to change the appearance of the points.
#
# ### Colors
#
# Use `col="_color_"` to add a color to the points:
#
#
# ```r
# # Create a scatter plot with x-coordinates ranging from 1 to 10
# # Customize the color of the points to be red
# plot(1:10, col="red")
# ```
#
# 1. **Creating a Scatter Plot:**
#    - The `plot()` function is used to create a scatter plot.
#    - We provide a single argument: `1:10`.
#    - The `1:10` expression generates a sequence of integers from 1 to 10.
#
# 2. **Customizing the Plot (Color):**
#    - The `col` parameter specifies the color of the points in the scatter plot.
#    - In this case, we set it to "red."
#
# 3. **Result (Expected Plot):**
#    - The plot will display points along the x-axis from 1 to 10.
#    - All points will be colored red.
#
# The resulting scatter plot would show red points at positions (1, 1), (2, 2), ..., (10, 10). 📊👍 ¹.

# %%
# Create a scatter plot with x-coordinates ranging from 1 to 10
# Customize the color of the points to be red
plot(1:10, col="red")
# Out:
# plot without title

# %% [markdown]
# ### Size `cex=_number_`
#
# Use `cex=_number_` to change the size of the points (`1` is default, while `0.5` means 50% smaller, and `2` means 100% larger).
#
# The **`cex`** parameter in R stands for **"character expansion"**. It is used to control the size of various graphical elements, such as symbols (points) and text, relative to the default size. Specifically:
#
# 1. **Symbols (Points) Size:**
#    - The `cex` parameter changes the size of symbols (points) in plots.
#    - By default, the value of `cex` is 1.
#    - A value greater than 1 (e.g., 2) will increase the size of symbols.
#    - A value less than 1 (e.g., 0.5) will decrease the size of symbols.
#
# 2. **Text Size:**
#    - The `cex` parameter also affects the size of text elements in plots.
#    - For example:
#      - `cex.main`: Changes the size of the plot title.
#      - `cex.lab`: Changes the size of x-axis and y-axis labels.
#      - `cex.axis`: Changes the size of axis tick mark annotations.
#
# Feel free to adjust the `cex` value to create plots with the exact sizes you desire! 📊👍
#
#
# ```r
# # Create a scatter plot with x-coordinates ranging from 1 to 10
# # The 'cex' parameter is set to 2, which controls the size of the points
# plot(1:10, cex=2)
# ```
#
# 1. **Creating a Scatter Plot:**
#    - The `plot()` function is used to create a scatter plot.
#    - We provide a single argument: `1:10`.
#    - The `1:10` expression generates a sequence of integers from 1 to 10.
#
# 2. **Customizing the Plot (Point Size):**
#    - The `cex` parameter specifies the size of the points in the scatter plot.
#    - A value of 2 means that the points will be twice as large as the default size.
#
# 3. **Result (Expected Plot):**
#    - The plot will display points along the x-axis from 1 to 10.
#    - All points will be larger than the default size due to the `cex=2` setting.
#
# The resulting scatter plot would show larger points at positions (1, 1), (2, 2), ..., (10, 10). 📊👍 ¹.
#
# Source:
#
# (1) Understanding plot() Function in R - Basics of Graph Plotting. https://www.digitalocean.com/community/tutorials/plot-function-in-r.
# (2) R Graphics - Plotting - W3Schools. https://www.w3schools.com/r/r_graph_plot.asp.
# (3) R plot() Function (with Examples) - Programiz. https://www.programiz.com/r/plot-function.
# (4) plot function - RDocumentation. https://www.rdocumentation.org/packages/graphics/versions/3.6.2/topics/plot.

# %%
# Create a scatter plot with x-coordinates ranging from 1 to 10
# The 'cex' parameter is set to 2, which controls the size of the points
plot(1:10, cex=2)
# Out:
# plot without title

# %% [markdown]
# ### Point Shape
#
# Use `pch` with a value from 0 to 25 to change the point shape format:
#
# The **`pch`** parameter stands for **"plot characters"**. It is an argument used in various plotting functions, such as `plot()`, `points()`, and `lines()`, to specify the type of symbol or marker to be used in the plot. The `pch` value determines the shape of the points (symbols) displayed on the graph. R provides a variety of built-in shapes (plot characters) that can be customized using the `pch` parameter.
#
#
# ```r
# # Create a scatter plot with x-coordinates ranging from 1 to 10
# # Customize the point shape (pch) to be filled squares (value 25)
# # Adjust the size of the points (cex) to be twice the default size (value 2)
# plot(1:10, pch=25, cex=2)
# ```
#
# 1. **Creating a Scatter Plot:**
#    - The `plot()` function is used to create a scatter plot.
#    - We provide a single argument: `1:10`.
#    - The `1:10` expression generates a sequence of integers from 1 to 10.
#
# 2. **Customizing the Plot (Point Shape and Size):**
#    - The `pch` parameter specifies the shape of the points (markers) in the scatter plot.
#    - A value of 25 corresponds to filled squares.
#    - The `cex` parameter controls the size of the points relative to the default size.
#    - A value of 2 means that the points will be twice as large as the default size.
#
# 3. **Result (Expected Plot):**
#    - The plot will display filled squares (points) along the x-axis from 1 to 10.
#    - The squares will be larger than the default size due to the `cex=2` setting.
#
# The resulting scatter plot would show filled squares at positions (1, 1), (2, 2), ..., (10, 10). 📊👍 ¹.
#
# Source:
#
# (1) Understanding plot() Function in R - Basics of Graph Plotting. https://www.digitalocean.com/community/tutorials/plot-function-in-r.
#
# (2) R Graphics - Plotting - W3Schools. https://www.w3schools.com/r/r_graph_plot.asp.
#
# (3) R plot() Function (with Examples) - Programiz. https://www.programiz.com/r/plot-function.
#
# (4) plot function - RDocumentation. https://www.rdocumentation.org/packages/graphics/versions/3.6.2/topics/plot.

# %%
# Create a scatter plot with x-coordinates ranging from 1 to 10
# Customize the point shape (pch) to be filled squares (value 25)
# Adjust the size of the points (cex) to be twice the default size (value 2)
plot(1:10, pch=25, cex=3)
# Out:
# plot without title

# %%
# Create a scatter plot with x-coordinates ranging from 1 to 10
# Customize the point shape (pch) to be filled squares (value 25)
# Adjust the size of the points (cex) to be twice the default size (value 2)
plot(1:10, pch = 22, col = "blue", bg = "blue", cex = 2)
# Out:
# plot without title

# %% [markdown]
# The values of the `pch` parameter ranges from 0 to 25, which means that we can choose up to 26 different types of point shapes:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_plot_pch2.png)

# %%
#using points
# Create a scatter plot with unfilled circles (pch = 1)
plot(1:10, pch = 1, col = "blue")

# Add filled circles with a different background color
points(1:10, pch = 21, col = "red", bg = "yellow")
# Out:
# plot without title

# %% [markdown]
# #Exercises on Graphs

# %% [markdown]
# **Exercise 1: Super Easy - Plotting Your Day (Line Graph)**
#
# **Objective:** Visualize your daily activities using a simple line graph.
#
# **Instructions:**
#
# 1. **Create data:** Use `c()` to create two vectors: one for time slots (e.g., "8:00 AM", "10:00 AM", ...) and another for activity levels (e.g., "0" for inactive, "1" for moderate activity, "2" for high activity). Make sure both vectors have the same length.
# 2. **Plot the points:** Use `plot(your_time_vector, your_activity_vector)` to draw a line connecting the activity levels at each time slot.
# 3. **Customize the graph:** Add a title using `main = "My Daily Activity"` and labels for the axes using `xlab = "Time"` and `ylab = "Activity Level"`.
# 4. **Challenge:** Can you color-code the activity levels (e.g., green for low, orange for medium, red for high) using the `col` parameter?
#
# **Code Snippet:**
#
# ```R
# # Step 1: Create data (replace with your time slots and activity levels)
# time_slots <- c("8:00 AM", "10:00 AM", "12:00 PM", "2:00 PM", "4:00 PM", "6:00 PM")
# activity_levels <- c(0, 1, 2, 1, 0, 0)
#
# # Step 2: Plot the line
# plot(time_slots, activity_levels)
#
# # Step 3: Customize the graph
# main <- "My Daily Activity"
# xlab <- "Time"
# ylab <- "Activity Level"
# title(main)
# xlabel(xlab)
# ylabel(ylab)
#
# # Step 4: Challenge (add col argument with color values)
# # ... code for color-coding activity levels
# ```
#
# **Exercise 2: Easy - Comparing Movie Ratings (Scatter Plot)**
#
# **Objective:** Explore the relationship between release year and rating for a set of movies.
#
# **Instructions:**
#
# 1. **Load data:** Use `read.csv()` to import a sample movie dataset (e.g., from Kaggle or UCI Machine Learning Repository) containing title, release year, and rating.
# 2. **Create the scatter plot:** Use `plot(year, rating, pch = 16)` to draw a scatter plot, where `year` is the release year vector and `rating` is the rating vector. `pch = 16` sets the point shape to a circle.
# 3. **Add labels and title:** Use `main = "Movie Ratings Over Time"`, `xlab = "Release Year"` and `ylabel = "Rating"` to label the axes and add a title.
# 4. **Challenge:** Can you color-code the points based on genre using the `col` parameter (e.g., blue for Action, green for Comedy)?
#
# **Code Snippet:**
#
# ```R
# # Step 1: Load data (replace with your chosen dataset path)
# movie_data <- read.csv("path/to/movie_data.csv")
#
# # Step 2: Create the scatter plot
# year <- movie_data$release_year
# rating <- movie_data$rating
# plot(year, rating, pch = 16)
#
# # Step 3: Add labels and title
# main <- "Movie Ratings Over Time"
# xlab <- "Release Year"
# ylab <- "Rating"
# title(main)
# xlabel(xlab)
# ylabel(ylab)
#
# # Step 4: Challenge (add col argument with color values based on genre)
# # ... code for color-coding by genre
# ```
#
# **Exercise 3: Medium - Visualizing Sleep Patterns (Bar Graph)**
#
# **Objective:** Analyze your sleep duration over a week using a bar graph.
#
# **Instructions:**
#
# 1. **Create data:** Use `c()` to create two vectors: one for days of the week ("Monday", "Tuesday", ...) and another for sleep durations in hours.
# 2. **Draw the bar graph:** Use `barplot(sleep_durations, names = days_of_week)` to create a bar graph with bars representing sleep durations for each day. `names = days_of_week` sets the x-axis labels.
# 3. **Customize the graph:** Add a title using `main = "My Weekly Sleep Pattern"` and labels for the axes using `xlab = "Day"` and `ylab = "Sleep Duration (hours)

# %% [markdown]
# ## Solutions with Explanatory Comments:
#
# **Exercise 1: Easy - Plotting Your Day (Line Graph)**
#
# ```r
# # Step 1: Create data (replace with your time slots and activity levels)
# time_slots <- c("8:00 AM", "10:00 AM", "12:00 PM", "2:00 PM", "4:00 PM", "6:00 PM")
# activity_levels <- c(0, 1, 2, 1, 0, 0)
#
# # Step 2: Plot the line
# plot(time_slots, activity_levels, type = "l", main = "My Daily Activity")
#
# # Add labels for axes and customize appearance
# xlabel("Time")
# ylabel("Activity Level")
# pch = 19  # Use circle symbol for points
# cex = 1.5  # Increase point size for better visibility
#
# # Step 4: Challenge (color-code activity levels)
# col <- c("green", "orange", "red")  # Colors for low, medium, high activity
# colors <- ifelse(activity_levels == 0, col[1],
#                  ifelse(activity_levels == 1, col[2], col[3]))  # Assign colors based on level
# plot(time_slots, activity_levels, type = "l", main = "My Daily Activity",
#      col = colors, pch = 19, cex = 1.5)
# ```
#
# **Explanation:**
#
# - `type = "l"` is added to `plot()` to explicitly specify a line graph.
# - `main = "My Daily Activity"` sets the title.
# - `xlabel()` and `ylabel()` add labels for the x and y axes, respectively.
# - `pch = 19` changes the point shape to a circle.
# - `cex = 1.5` increases the point size for clearer visualization.
# - The color-coding challenge uses `ifelse()` to assign colors based on activity levels and stores them in the `colors` vector.
# - The final `plot()` call includes the updated `col` argument to apply the colors.
#
# **Exercise 2: Easy - Comparing Movie Ratings (Scatter Plot)**
#
# ```r
# # Step 1: Load data (replace with your chosen dataset path)
# movie_data <- read.csv("path/to/movie_data.csv")
#
# # Step 2: Create the scatter plot
# year <- movie_data$release_year
# rating <- movie_data$rating
# plot(year, rating, pch = 16, main = "Movie Ratings Over Time",
#      xlab = "Release Year", ylab = "Rating")
#
# # Step 4: Challenge (color-code by genre)
# genre <- movie_data$genre  # Assuming a "genre" column exists
# colors <- rainbow(nlevels(genre))  # Create unique colors for each genre
# plot(year, rating, pch = 16, main = "Movie Ratings Over Time",
#      xlab = "Release Year", ylab = "Rating", col = colors[genre])
# ```
#
# **Explanation:**
#
# - The code assumes the dataset has columns named "release_year", "rating", and "genre".
# - `colors <- rainbow(nlevels(genre))` creates a color palette using the `rainbow()` function, ensuring unique colors for each genre.
# - The final `plot()` includes `col = colors[genre]` to assign colors based on the corresponding genre in each data point.
#
# **Exercise 3: Medium - Visualizing Sleep Patterns (Bar Graph)**
#
# ```r
# # Step 1: Create data (replace with your day names and sleep durations)
# days_of_week <- c("Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun")
# sleep_durations <- c(7.5, 6.8, 8.0, 7.2, 6.5, 8.8, 9.0)
#
# # Step 2: Draw the bar graph
# barplot(sleep_durations, names = days_of_week, main = "My Weekly Sleep Pattern",
#        xlab = "Day", ylab = "Sleep Duration (hours)")
#
# # Step 3: Customize the graph (optional)
# # You can adjust bar colors, add gridlines, etc. with additional arguments
# ```
#
# **Explanation:**
#
# - The code assumes you have vectors named "days_of_week" and "sleep_durations".
# - The `barplot()` function creates the bars, with `names = days_of_week` setting the x-axis labels.
# - The `main`, `x

# %% [markdown]
# #Line Graphs

# %% [markdown]
# * * *
#
# Line Graphs
# -----------
#
# A line graph has a line that connects all the points in a diagram.
#
# To create a line, use the `plot()` function and add the `type` parameter with a value of `"l"`:
#
#
#
# ```r
# # Example R code: Plotting a line graph
# # We'll create a simple line plot using the plot() function
#
# # Generate a sequence of numbers from 1 to 10
# x_values <- 1:10
#
# # Plot the sequence against itself (y = x)
# # The 'type' argument specifies that we want a line plot ('l')
# plot(x_values, type = "l")
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Sequence (`x_values`)**:
#    - We create a numeric vector called `x_values` containing the numbers from 1 to 10 using the `1:10` notation.
#    - This vector represents the x-axis values for our plot.
#
# 2. **Plotting the Line (`plot(x_values, type = "l")`)**:
#    - The `plot()` function is a versatile tool for creating various types of graphs in R.
#    - In this case, we use it to create a **line plot**.
#    - The `x_values` serve as the x-coordinates, and the corresponding y-coordinates are assumed to be the same (i.e., y = x).
#    - The `type = "l"` argument specifies that we want to connect the points with a line.
#    - The resulting plot will display a straight line connecting the points (1,1), (2,2), ..., (10,10).
#
# Remember that the `plot()` function in R is quite powerful and can be customized further by adjusting parameters such as colors, labels, titles, and more. Feel free to explore additional options to create more complex and informative plots! 📊👨‍🔬🔍
#
# For more details, you can refer to the [DigitalOcean tutorial](https://www.digitalocean.com/community/tutorials/plot-function-in-r) on understanding the `plot()` function in R.
#
#
#
# * * *

# %% [markdown]
# ###Preferred Method

# %%
# Example R code: Plotting a line graph
# We'll create a simple line plot using the plot() function

# Generate a sequence of numbers from 1 to 10
x_values <- 1:10

# Plot the sequence against itself (y = x)
# The 'type' argument specifies that we want a line plot ('l')
plot(x_values, type = "l")
# Out:
# plot without title

# %% [markdown]
# **Method 2**

# %%
plot(1:10, type="l") #although this method is quick but some environments may not render the image properly.
# Out:
# plot without title

# %% [markdown]
# Line Color
# ----------
#
# The line color is black by default. To change the color, use the `col` parameter:
#
#
# ```r
# # Example R code: Plotting a line graph
# # We'll create a simple line plot using the plot() function
#
# # Generate a sequence of numbers from 1 to 10
# x_values <- 1:10
#
# # Plot the sequence against itself (y = x)
# # The 'type' argument specifies that we want a line plot ('l')
# plot(x_values, type = "l", col = "blue")
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Sequence (`x_values`)**:
#    - We create a numeric vector called `x_values` containing the numbers from 1 to 10 using the `1:10` notation.
#    - This vector represents the x-axis values for our plot.
#
# 2. **Plotting the Line (`plot(x_values, type = "l", col = "blue")`)**:
#    - The `plot()` function is a versatile tool for creating various types of graphs in R.
#    - In this case, we use it to create a **line plot**.
#    - The `x_values` serve as the x-coordinates, and the corresponding y-coordinates are assumed to be the same (i.e., y = x).
#    - The `type = "l"` argument specifies that we want to connect the points with a line.
#    - The `col = "blue"` argument sets the color of the line to blue.
#    - The resulting plot will display a straight blue line connecting the points (1,1), (2,2), ..., (10,10).
#
# Remember that the `plot()` function in R is quite powerful and can be customized further by adjusting parameters such as colors, labels, titles, and more. Feel free to explore additional options to create more complex and informative plots! 📊👨‍🔬🔍
#
# For more details, you can refer to the [DigitalOcean tutorial](https://www.digitalocean.com/community/tutorials/plot-function-in-r) on understanding the `plot()` function in R.
#
#
# * * *

# %%
# Example R code: Plotting a line graph
# We'll create a simple line plot using the plot() function

# Generate a sequence of numbers from 1 to 10
x_values <- 1:10

# Plot the sequence against itself (y = x)
# The 'type' argument specifies that we want a line plot ('l')
plot(x_values, type = "l", col = "blue")
# Out:
# plot without title

# %% [markdown]
# * * *
#
# Line Width
# ----------
#
# To change the width of the line, use the `lwd` parameter (`1` is default, while `0.5` means 50% smaller, and `2` means 100% larger):
#
#
# ```r
# # Example R code: Plotting a line graph
# # We'll create a simple line plot using the plot() function
#
# # Generate a sequence of numbers from 1 to 10
# x_values <- 1:10
#
# # Plot the sequence against itself (y = x)
# # The 'type' argument specifies that we want a line plot ('l')
# # The 'lwd' argument sets the line width to 2 (thicker line)
# plot(x_values, type = "l", lwd = 2)
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Sequence (`x_values`)**:
#    - We create a numeric vector called `x_values` containing the numbers from 1 to 10 using the `1:10` notation.
#    - This vector represents the x-axis values for our plot.
#
# 2. **Plotting the Line (`plot(x_values, type = "l", lwd = 2)`)**:
#    - The `plot()` function is a versatile tool for creating various types of graphs in R.
#    - In this case, we use it to create a **line plot**.
#    - The `x_values` serve as the x-coordinates, and the corresponding y-coordinates are assumed to be the same (i.e., y = x).
#    - The `type = "l"` argument specifies that we want to connect the points with a line.
#    - The `lwd = 2` argument sets the line width to 2 (making the line thicker).
#    - The resulting plot will display a straight line connecting the points (1,1), (2,2), ..., (10,10) with a thicker line.
#
# Remember that the `plot()` function in R is quite powerful and can be customized further by adjusting parameters such as colors, labels, titles, and more. The `lwd` parameter allows you to control the thickness of the line, making it more visually prominent. Feel free to explore additional options to create more complex and informative plots! 📊👨‍🔬🔍
#
# For more details, you can refer to the [DigitalOcean tutorial](https://www.digitalocean.com/community/tutorials/plot-function-in-r) on understanding the `plot()` function in R.
#
#
# * * *

# %%
# Example R code: Plotting a line graph
# We'll create a simple line plot using the plot() function

# Generate a sequence of numbers from 1 to 10
x_values <- 1:10

# Plot the sequence against itself (y = x)
# The 'type' argument specifies that we want a line plot ('l')
# The 'lwd' argument sets the line width to 14 (thicker line)
plot(x_values, type = "l", lwd = 14)
# Out:
# plot without title

# %% [markdown]
# Line Styles
# -----------
#
# The line is solid by default. Use the `lty` parameter with a value from **0 to 6** to specify the line format.
#
# For example, `lty=3` will display a dotted line instead of a solid line:
#
# Available parameter values for `lty`:
#
# *   `0` removes the line
# *   `1` displays a solid line
# *   `2` displays a dashed line
# *   `3` displays a dotted line
# *   `4` displays a "dot dashed" line
# *   `5` displays a "long dashed" line
# *   `6` displays a "two dashed" line
#
# ```r
# # Example R code: Plotting a customized line graph
# # We'll create a line plot with specific attributes using the plot() function
#
# # Generate a sequence of numbers from 1 to 10
# x_values <- 1:10
#
# # Plot the sequence against itself (y = x)
# # The 'type' argument specifies that we want a line plot ('l')
# # The 'lwd' argument sets the line width to 5 (thicker line)
# # The 'lty' argument sets the line type to dashed (type 3)
# plot(x_values, type = "l", lwd = 5, lty = 3)
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Sequence (`x_values`)**:
#    - We create a numeric vector called `x_values` containing the numbers from 1 to 10 using the `1:10` notation.
#    - This vector represents the x-axis values for our plot.
#
# 2. **Plotting the Line (`plot(x_values, type = "l", lwd = 5, lty = 3)`)**:
#    - The `plot()` function is a versatile tool for creating various types of graphs in R.
#    - In this case, we use it to create a **line plot**.
#    - The `x_values` serve as the x-coordinates, and the corresponding y-coordinates are assumed to be the same (i.e., y = x).
#    - The `type = "l"` argument specifies that we want to connect the points with a line.
#    - The `lwd = 5` argument sets the line width to 5 (making the line thicker).
#    - The `lty = 3` argument sets the line type to dashed (type 3).
#    - The resulting plot will display a thicker, dashed line connecting the points (1,1), (2,2), ..., (10,10).
#
# Remember that the `plot()` function in R is quite powerful and can be customized further by adjusting parameters such as colors, labels, titles, and more. The `lwd` and `lty` parameters allow you to control the thickness and style of the line, respectively. Feel free to explore additional options to create more complex and eye-catching plots! 📊👨‍🔬🔍
#
# For more details, you can refer to the [DigitalOcean tutorial](https://www.digitalocean.com/community/tutorials/plot-function-in-r) on understanding the `plot()` function in R.
#
#
#
# * * *

# %%
# Example R code: Plotting a customized line graph
# We'll create a line plot with specific attributes using the plot() function

# Generate a sequence of numbers from 1 to 10
x_values <- 1:10

# Plot the sequence against itself (y = x)
# The 'type' argument specifies that we want a line plot ('l')
# The 'lwd' argument sets the line width to 5 (thicker line)
# The 'lty' argument sets the line type to dashed (type 3)
plot(x_values, type = "l", lwd = 5, lty = 3)
# Out:
# plot without title

# %% [markdown]
# Multiple Lines
# --------------
#
# To display more than one line in a graph, use the `plot()` function together with the `lines()` function:
#
# ### Example
#
# ```r
# # Example R code: Plotting two lines
# # We'll create a line plot with two lines using the plot() and lines() functions
#
# # Create two numeric vectors 'line1' and 'line2'
# line1 <- c(1, 2, 3, 4, 5, 10)
# line2 <- c(2, 5, 7, 8, 9, 10)
#
# # Plot the first line (line1) in blue
# plot(line1, type = "l", col = "blue")
#
# # Add the second line (line2) to the existing plot in red
# lines(line2, type = "l", col = "red")
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating Two Numeric Vectors (`line1` and `line2`)**:
#    - We define two numeric vectors: `line1` and `line2`.
#    - `line1` contains the values `(1, 2, 3, 4, 5, 10)`.
#    - `line2` contains the values `(2, 5, 7, 8, 9, 10)`.
#
# 2. **Plotting the First Line (`plot(line1, type = "l", col = "blue")`)**:
#    - The `plot()` function creates a new plot.
#    - We pass the `line1` vector as the y-values.
#    - The `type = "l"` argument specifies that we want to connect the points with a line.
#    - The `col = "blue"` argument sets the color of the line to blue.
#    - The resulting plot displays a blue line connecting the points `(1,1)`, `(2,2)`, ..., `(10,10)`.
#
# 3. **Adding the Second Line (`lines(line2, type = "l", col = "red")`)**:
#    - The `lines()` function adds a line to an existing plot.
#    - We pass the `line2` vector as the y-values.
#    - The `type = "l"` argument ensures that the points are connected with a line.
#    - The `col = "red"` argument sets the color of the line to red.
#    - The second line connects the points `(2,2)`, `(5,5)`, ..., `(10,10)`.
#
# The resulting plot will show both lines on the same graph, with one in blue and the other in red. 📊🔍
#
# Remember that R provides powerful tools for creating customized plots, and you can further explore additional options to enhance your visualizations! For more details, you can refer to the [DigitalOcean tutorial](https://www.digitalocean.com/community/tutorials/plot-function-in-r) on understanding the `plot()` function in R.
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_plot_multi.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_line_multi)

# %%
# Example R code: Plotting two lines
# We'll create a line plot with two lines using the plot() and lines() functions

# Create two numeric vectors 'line1' and 'line2'
line1 <- c(1, 2, 3, 4, 5, 10)
line2 <- c(2, 5, 7, 8, 9, 10)

# Plot the first line (line1) in blue
plot(line1, type = "l", col = "blue")

# Add the second line (line2) to the existing plot in red
lines(line2, type = "l", col = "red")
# Out:
# plot without title

# %% [markdown]
# #Exercises on Graphs for you to Practice

# %% [markdown]
# **Exercise 1: Super Easy - Plotting Your Daily Mood (Line Graph)**
#
# **Objective:** Visualize your mood throughout the day using a line graph.
#
# **Instructions:**
#
# 1. **Create data:** Use `c()` to create two vectors: one for time slots (e.g., "8:00 AM", "10:00 AM", ...) and another for mood ratings (e.g., 1 for low, 3 for high). Make sure both vectors have the same length.
# 2. **Plot the line:** Use `plot(time_slots, mood_ratings, type = "l")` to draw a line representing your mood at each time slot.
# 3. **Customize the graph:** Add a title using `main = "My Day Mood"` and labels for the axes using `xlab = "Time"` and `ylab = "Mood Rating"`.
# 4. **Challenge:** Choose two distinct colors using `col` (e.g., blue for good mood, red for bad mood) and customize the line style using `lty` (e.g., `lty = 3` for dotted lines).
#
# **Code Snippet:**
#
# ```r
# # Step 1: Create data (replace with your time slots and mood ratings)
# time_slots <- c("8:00 AM", "10:00 AM", "12:00 PM", "2:00 PM", "4:00 PM", "6:00 PM")
# mood_ratings <- c(2, 1, 3, 1, 2, 3)
#
# # Step 2: Plot the line
# plot(time_slots, mood_ratings, type = "l")
#
# # Step 3: Customize the graph
# main <- "My Day Mood"
# xlab <- "Time"
# ylab <- "Mood Rating"
# title(main)
# xlabel(xlab)
# ylabel(ylab)
#
# # Step 4: Challenge (add col and lty arguments)
# # ... code for color and line style customization
# ```
#
# **Exercise 2: Easy - Comparing Temperature Changes (Multiple Lines)**
#
# **Objective:** Plot historical temperature data for two cities in the same graph.
#
# **Instructions:**
#
# 1. **Load data:** Create two vectors named `city1_temps` and `city2_temps` containing temperature values for each city (you can create dummy data or use a sample dataset).
# 2. **Plot multiple lines:** Use `plot(city1_temps, type = "l", col = "blue")` to plot the first city's temperatures in blue. Then, use `lines(city2_temps, type = "l", col = "red")` to add the second city's temperatures in red.
# 3. **Customize the graph:** Add a title, axis labels, and a legend (using `legend()` with appropriate labels) to distinguish the lines.
# 4. **Challenge:** Explore different line styles using `lty` (e.g., `lty = 2` for dashed lines) and experiment with changing line widths using `lwd` (e.g., `lwd = 2` for thicker lines).
#
# **Code Snippet:**
#
# ```r
# # Step 1: Create data (replace with your desired temperatures)
# city1_temps <- c(15, 16, 18, 20, 22, 20)
# city2_temps <- c(18, 19, 21, 23, 22, 20)
#
# # Step 2: Plot multiple lines
# plot(city1_temps, type = "l", col = "blue")
# lines(city2_temps, type = "l", col = "red")
#
# # Step 3: Customize the graph
# main <- "Temperature Comparison"
# xlab <- "Day"
# ylab <- "Temperature (°C)"
# title(main)
# xlabel(xlab)
# ylabel(ylab)
# legend("topleft", c("City 1", "City 2"), col = c("blue", "red"), lty = c(1, 1))
#
# # Step 4: Challenge (experiment with lty and lwd)
# # ... code for changing line styles and widths
# ```
#
#
# **Exercise 3: Medium - Visualizing Activity Goals (Area Chart)**
#
# **Objective:** Track your progress towards daily activity goals using an area chart.
#
# **Instructions:**
#
# 1. **Create data:** Create vectors named `steps_goal`, `steps_taken` (containing your actual steps), and `time_slots` (representing time intervals) with the same length. Assign values to each vector that reflect your daily step goal and your actual steps at each time interval.
# 2. **Plot the area chart:** Use `plot(time_slots, steps_taken, type = "b")` to draw an area chart shaded below the line representing your actual steps.
# 3. **Add the goal line:** Use `lines(time_slots, steps_goal, col = "red", type = "l")` to add a straight line representing your daily step goal in red.
# 4. **Customize the graph:** Add a title using `main = "Daily Activity Progress"`, labels for the axes using `xlab = "Time"` and `ylab = "Steps"`, and adjust the area color using `col` (e.g., `col = "lightblue"`).
# 5. **Challenge:** If you have data for multiple days, explore stacking multiple area charts using `fill = c("lightblue", "lightgreen", ...)` to track progress over days.
#
# **Code Snippet:**
#
# ```r
# # Step 1: Create data (replace with your values)
# steps_goal <- c(10000, 10000, 10000)  # Daily goal for each time slot
# steps_taken <- c(7000, 8500, 9000)  # Actual steps at each time slot
# time_slots <- c("Morning", "Afternoon", "Evening")
#
# # Step 2: Plot the area chart
# plot(time_slots, steps_taken, type = "b", col = "lightblue")  # Adjust area color if desired
#
# # Step 3: Add the goal line
# lines(time_slots, steps_goal, col = "red", type = "l")
#
# # Step 4: Customize the graph
# main <- "Daily Activity Progress"
# xlab <- "Time"
# ylab <- "Steps"
# title(main)
# xlabel(xlab)
# ylabel(ylab)
#
# # Step 5: Challenge (stack area charts for multiple days)
# # ... code for stacking areas
#
# ```
#
# Remember to replace the sample data with your actual values and explore the `col`, `fill`, and other customization options in `plot()` to make the chart informative and visually appealing.

# %% [markdown]
# #Solutions to Exercises on Line Graph

# %% [markdown]
# **Exercise 1: Easy - Plotting Your Day Mood (Line Graph)**
#
# **Solution:**
#
# ```r
# # Step 1: Create data (replace with your time slots and mood ratings)
# time_slots <- c("8:00 AM", "10:00 AM", "12:00 PM", "2:00 PM", "4:00 PM", "6:00 PM")
# mood_ratings <- c(2, 1, 3, 1, 2, 3)
#
# # Step 2: Plot the line and customize
# plot(time_slots, mood_ratings, type = "l", col = "blue", main = "My Day Mood",
#      xlab = "Time", ylab = "Mood Rating")
#
# # Step 3: Challenge (add color and line style)
# lines(time_slots, mood_ratings > 2, type = "l", col = "red", lty = 3)  # Red dotted line for good mood
#
# # Additional customization (optional)
# legend("topright", c("Low/Neutral", "Good"), col = c("blue", "red"), lty = c(1, 3))
# ```
#
# **Explanation:**
#
# - `plot()` creates the line graph with basic settings.
# - `col = "blue"` sets the line color to blue for visualizing all mood ratings.
# - The challenge uses another `lines()` call to add a red dotted line for ratings above 2 (considered good).
# - `lty = 3` changes the line style to dotted for the good mood line.
# - The optional legend helps distinguish the lines using labels and color/style cues.
#
# **Exercise 2: Easy - Comparing Temperature Changes (Multiple Lines)**
#
# **Solution:**
#
# ```r
# # Step 1: Create data (replace with your desired temperatures)
# city1_temps <- c(15, 16, 18, 20, 22, 20)
# city2_temps <- c(18, 19, 21, 23, 22, 20)
#
# # Step 2: Plot multiple lines and customize
# plot(city1_temps, type = "l", col = "blue", lwd = 1.5, main = "Temperature Comparison",
#      xlab = "Day", ylab = "Temperature (°C)")
# lines(city2_temps, type = "l", col = "red", lwd = 1.5, lty = 2)  # Dashed line for city 2
# legend("topleft", c("City 1", "City 2"), col = c("blue", "red"), lty = c(1, 2))
#
# # Step 3: Challenge (experiment with lty and lwd)
# # You can try different line style values (0-6) and width values (e.g., lwd = 2)
#
# # Additional customization (optional)
# grid(TRUE)  # Add gridlines for better readability
# ```
#
# **Explanation:**
#
# - The initial `plot()` creates the blue line for city 1 with increased width (`lwd = 1.5`).
# - The following `lines()` adds the red line for city 2, also with wider strokes and a dashed line style (`lty = 2`).
# - The legend clarifies which line represents each city.
# - The challenge encourages experimenting with different line styles and widths to personalize the visualization.
# - The optional `grid()` adds gridlines for improved data interpretation.
#
# I hope these solutions and explanations are helpful! Remember to adjust the data and customization options to match your specific needs and preferences.

# %% [markdown]
# **Exercise 3: Medium - Visualizing Activity Goals (Area Chart)**
#
# **Objective:** Track your progress towards daily activity goals using an area chart.
#
# **Instructions:**
#
# 1. **Create data:**
#
#    ```R
#    # Replace with your values for daily step goal and actual steps
#    steps_goal <- c(10000, 10000, 10000)  # Daily goal for each time slot
#    steps_taken <- c(7000, 8500, 9000)  # Actual steps at each time slot
#    time_slots <- c("Morning", "Afternoon", "Evening")
#    ```
#
# 2. **Plot the area chart:**
#
#    ```R
#    # Plot the actual steps with a filled area beneath (type="b")
#    plot(time_slots, steps_taken, type = "b", col = "lightblue")
#    ```
#
#    **Explanation:**
#    - `plot(time_slots, steps_taken, type = "b")` creates the chart.
#    - `type = "b"` specifies an area chart, filling the area below the line.
#    - `col = "lightblue"` sets the area color (you can choose your preference).
#
# 3. **Add the goal line:**
#
#    ```R
#    # Add a red line for the daily goal steps
#    lines(time_slots, steps_goal, col = "red", type = "l")
#    ```
#
#    **Explanation:**
#    - `lines(time_slots, steps_goal, col = "red", type = "l")` adds another line on top.
#    - `col = "red"` sets the line color to red.
#    - `type = "l"` specifies a solid line.
#
# 4. **Customize the graph:**
#
#    ```R
#    # Add title, axis labels, and adjust formatting
#    main <- "Daily Activity Progress"
#    xlab <- "Time of Day"
#    ylab <- "Steps"
#    title(main)
#    xlabel(xlab)
#    ylabel(ylab)
#    ```
#
#    **Explanation:**
#    - `main <- ...`, `xlab <- ...`, and `ylab <- ...` set labels for title and axes.
#    - `title(main)`, `xlabel(xlab)`, and `ylabel(ylab)` display them on the plot.
#
# 5. **Challenge (optional):**
#
#    ```R
#    # Stack area charts for multiple days (replace with your data)
#    # ... code for stacking areas
#    ```
#
#    **Explanation:**
#    - This step requires multiple days of data for each time slot.
#    - You can use `fill = c("lightblue", "lightgreen", ...)` to assign different colors to each day's area.
#    - Experiment with stacking multiple `plot()` calls for each day, adjusting `fill` for visual clarity.
#
# Remember to replace the sample data with your actual values and customize the chart appearance to enhance its meaningfulness.

# %% [markdown]
# # Scatter Plots in R

# %% [markdown]
# * * *
#
# Scatter Plots
# -------------
#
# You learned from the [Plot chapter](https://www.w3schools.com/r/r_graph_plot.asp) that the `plot()` function is used to plot numbers against each other.
#
# A "scatter plot" is a type of plot used to display the relationship between two numerical variables, and plots one dot for each observation.
#
# It needs two vectors of same length, one for the x-axis (horizontal) and one for the y-axis (vertical):
#
# ### Example
# Certainly! Let's break down the provided R code snippet step by step:
#
# ```R
# # Example R code: Creating a scatter plot
# # We'll plot the points defined by vectors 'x' and 'y'
#
# # Create two numeric vectors 'x' and 'y'
# x <- c(5, 7, 8, 7, 2, 2, 9, 4, 11, 12, 9, 6)
# y <- c(99, 86, 87, 88, 111, 103, 87, 94, 78, 77, 85, 86)
#
# # Plot the points (x, y) as a scatter plot
# plot(x, y)
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating Two Numeric Vectors (`x` and `y`)**:
#    - We define two numeric vectors:
#      - `x` contains the values `(5, 7, 8, 7, 2, 2, 9, 4, 11, 12, 9, 6)`.
#      - `y` contains the values `(99, 86, 87, 88, 111, 103, 87, 94, 78, 77, 85, 86)`.
#
# 2. **Plotting the Points (`plot(x, y)`)**:
#    - The `plot()` function creates a scatter plot.
#    - We pass the vectors `x` and `y` as the x-coordinates and y-coordinates, respectively.
#    - The resulting plot displays points at the coordinates `(x[1], y[1])`, `(x[2], y[2])`, ..., `(x[12], y[12])`.
#
# The scatter plot visually represents the relationship between the `x` and `y` values. Each point corresponds to a pair of values from the vectors. 📊🔍
#
# For more details on creating plots in R, you can explore additional resources such as [DataCamp's R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r) ¹..
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_scatterplot.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_scatterplot)

# %%
# Example R code: Creating a scatter plot
# We'll plot the points defined by vectors 'x' and 'y'

# Create two numeric vectors 'x' and 'y'
x <- c(5, 7, 8, 7, 2, 2, 9, 4, 11, 12, 9, 6)
y <- c(99, 86, 87, 88, 111, 103, 87, 94, 78, 77, 85, 86)

# Plot the points (x, y) as a scatter plot
plot(x, y)
# Out:
# plot without title

# %% [markdown]
# The observation in the example above should show the result of 12 cars passing by.
#
# That might not be clear for someone who sees the graph for the first time, so let's add a header and different labels to describe the scatter plot better:
#
# ### Example
#
# ```R
# # Example R code: Creating a scatter plot
# # We'll plot the points defined by vectors 'x' and 'y'
#
# # Create two numeric vectors 'x' and 'y'
# x <- c(5, 7, 8, 7, 2, 2, 9, 4, 11, 12, 9, 6)
# y <- c(99, 86, 87, 88, 111, 103, 87, 94, 78, 77, 85, 86)
#
# # Plot the points (x, y) as a scatter plot
# plot(x, y, main = "Observation of Cars", xlab = "Car age", ylab = "Car speed")
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating Two Numeric Vectors (`x` and `y`)**:
#    - We define two numeric vectors:
#      - `x` contains the values `(5, 7, 8, 7, 2, 2, 9, 4, 11, 12, 9, 6)`.
#      - `y` contains the values `(99, 86, 87, 88, 111, 103, 87, 94, 78, 77, 85, 86)`.
#
# 2. **Plotting the Points (`plot(x, y, main = "Observation of Cars", xlab = "Car age", ylab = "Car speed")`)**:
#    - The `plot()` function creates a scatter plot.
#    - We pass the vectors `x` and `y` as the x-coordinates and y-coordinates, respectively.
#    - The `main` argument sets the title of the plot to "Observation of Cars".
#    - The `xlab` argument labels the x-axis as "Car age".
#    - The `ylab` argument labels the y-axis as "Car speed".
#    - The resulting plot displays points at the coordinates `(x[1], y[1])`, `(x[2], y[2])`, ..., `(x[12], y[12])`.
#
# The scatter plot visually represents the relationship between car age and car speed based on the given data points. Each point corresponds to a pair of values from the vectors. 📊🚗💨
#
# For more details on creating plots in R, you can explore additional resources such as the [DataCamp R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r).
#
# **Result:**
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_scatterplot_car.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_scatterplot_cars)

# %%
# Example R code: Creating a scatter plot
# We'll plot the points defined by vectors 'x' and 'y'

# Create two numeric vectors 'x' and 'y'
x <- c(5, 7, 8, 7, 2, 2, 9, 4, 11, 12, 9, 6)
y <- c(99, 86, 87, 88, 111, 103, 87, 94, 78, 77, 85, 86)

# Plot the points (x, y) as a scatter plot
plot(x, y, main = "Observation of Cars", xlab = "Car age", ylab = "Car speed")
# Out:
# Plot with title “Observation of Cars”

# %% [markdown]
# To recap, the observation in the example above is the result of 12 cars passing by.
#
# The **x-axis** shows how old the car is.
#
# The **y-axis** shows the speed of the car when it passes.
#
# Are there any relationships between the observations?
#
# It seems that the newer the car, the faster it drives, but that could be a coincidence, after all we only registered 12 cars.
#
# * * *
#
# * * *
#
# Compare Plots
# -------------
#
# In the example above, there seems to be a relationship between the car speed and age, but what if we plot the observations from another day as well? Will the scatter plot tell us something else?
#
# To compare the plot with another plot, use the `points()` function:
#
# ### Example
#
# ```r
# # Example R code: Creating a scatter plot with two data sets
# # We'll plot the points defined by vectors 'x1' and 'y1' (day one) and 'x2' and 'y2' (day two)
#
# # Day one: Age and speed of 12 cars
# x1 <- c(5, 7, 8, 7, 2, 2, 9, 4, 11, 12, 9, 6)
# y1 <- c(99, 86, 87, 88, 111, 103, 87, 94, 78, 77, 85, 86)
#
# # Day two: Age and speed of 15 cars
# x2 <- c(2, 2, 8, 1, 15, 8, 12, 9, 7, 3, 11, 4, 7, 14, 12)
# y2 <- c(100, 105, 84, 105, 90, 99, 90, 95, 94, 100, 79, 112, 91, 80, 85)
#
# # Create a scatter plot for day one (in red)
# plot(x1, y1, main = "Observation of Cars", xlab = "Car age", ylab = "Car speed", col = "red", cex = 2)
#
# # Add points for day two (in blue) to the existing plot
# points(x2, y2, col = "blue", cex = 2)
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating Two Sets of Numeric Vectors (`x1`, `y1`, `x2`, and `y2`)**:
#    - `x1` and `y1` represent the age and speed of 12 cars on day one.
#    - `x2` and `y2` represent the age and speed of 15 cars on day two.
#
# 2. **Plotting the Points (`plot(x1, y1, ...)`)**:
#    - The `plot()` function creates a scatter plot for day one.
#    - We pass the vectors `x1` and `y1` as the x-coordinates and y-coordinates, respectively.
#    - The `main` argument sets the title of the plot to "Observation of Cars".
#    - The `xlab` argument labels the x-axis as "Car age".
#    - The `ylab` argument labels the y-axis as "Car speed".
#    - The points are displayed in red, and their size is increased (`cex = 2`).
#
# 3. **Adding Points for Day Two (`points(x2, y2, ...)`)**:
#    - The `points()` function adds points to the existing plot.
#    - We pass the vectors `x2` and `y2` as the x-coordinates and y-coordinates for day two.
#    - These points are displayed in blue and have the same increased size (`cex = 2`).
#
# The resulting scatter plot visually compares the age-speed relationship of cars between day one and day two. 📊🚗💨
#
# For more details on creating scatter plots in R, you can explore additional resources such as [R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r).
#
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_scatterplot_car2.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_scatterplot_cars2)
#
# **Note:** To be able to see the difference of the comparison, you must assign different colors to the plots (by using the `col` parameter). Red represents the values of day 1, while blue represents day 2. Note that we have also added the `cex` parameter to increase the size of the dots.
#
# **Conclusion of observation:** By comparing the two plots, I think it is safe to say that they both gives us the same conclusion: the newer the car, the faster it drives.
#
# * * *

# %%
# Example R code: Creating a scatter plot with two data sets
# We'll plot the points defined by vectors 'x1' and 'y1' (day one) and 'x2' and 'y2' (day two)

# Day one: Age and speed of 12 cars
x1 <- c(5, 7, 8, 7, 2, 2, 9, 4, 11, 12, 9, 6)
y1 <- c(99, 86, 87, 88, 111, 103, 87, 94, 78, 77, 85, 86)

# Day two: Age and speed of 15 cars
x2 <- c(2, 2, 8, 1, 15, 8, 12, 9, 7, 3, 11, 4, 7, 14, 12)
y2 <- c(100, 105, 84, 105, 90, 99, 90, 95, 94, 100, 79, 112, 91, 80, 85)

# Create a scatter plot for day one (in red)
plot(x1, y1, main = "Observation of Cars", xlab = "Car age", ylab = "Car speed", col = "red", cex = 2)

# Add points for day two (in blue) to the existing plot
points(x2, y2, col = "blue", cex = 2)
# Out:
# Plot with title “Observation of Cars”

# %% [markdown]
# **Note:** To be able to see the difference of the comparison, you must assign different colors to the plots (by using the `col` parameter). Red represents the values of day 1, while blue represents day 2. Note that we have also added the `cex` parameter to increase the size of the dots.
#
# **Conclusion of observation:** By comparing the two plots, I think it is safe to say that they both gives us the same conclusion: the newer the car, the faster it drives.
# ***

# %% [markdown]
# #Exercises on Scatter Plot

# %% [markdown]
# **Exercise 1: Easy - Your Sleep Patterns (Scatter Plot)**
#
# **Objective:** Explore your sleep duration trends across the week using a scatter plot.
#
# **Instructions:**
#
# 1. **Create data:** Make two vectors named `days` (weekdays and weekend) and `sleep_durations` (corresponding sleep hours).
# 2. **Plot the scatter:** Use `plot(days, sleep_durations, type = "p")` to create a point-based scatter plot.
# 3. **Customize the graph:** Add a title `My Weekly Sleep`, axis labels with `xlab = "Day"` and `ylab = "Sleep Duration (hours)"`. Enhance readability with `col = c("blue", "orange")` for weekdays and weekends.
# 4. **Challenge:** Experiment with different point shapes and sizes using `pch` and `cex` (e.g., `pch = 19`, `cex = 1.5`). Consider adding a legend if many point shapes are used.
#
# **Code Snippet:**
#
# ```r
# # Step 1: Create data (replace with your values)
# days <- c("Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun")
# sleep_durations <- c(7.5, 6.8, 8.0, 7.2, 6.5, 8.8, 9.0)
#
# # Step 2: Plot the scatter
# plot(days, sleep_durations, type = "p", main = "My Weekly Sleep",
#      xlab = "Day", ylab = "Sleep Duration (hours)", col = c("blue", "orange")[days %in% c("Mon", "Tue", "Wed", "Thu", "Fri")])
#
# # Step 3: Challenge (experiment with pch and cex)
# # ... code for point shapes and sizes
#
# # Optional: Add a legend if many point shapes are used
# # ... code for legend using legend()
# ```
#
# **Exercise 2: Easy - Comparing Movie Ratings (Scatter Plot)**
#
# **Objective:** Visualize the relationship between release year and movie rating using a scatter plot.
#
# **Instructions:**
#
# 1. **Load data:** Create a sample dataset or load an existing one with columns for "release_year" and "rating".
# 2. **Plot the scatter:** Use `plot(release_year, rating, type = "p")` to create the scatter plot.
# 3. **Customize the graph:** Add a title, axis labels, and consider color-coding movies by genre (if available) using `col = genre`, and adjust transparency with `alpha` (e.g., `alpha = 0.5`).
# 4. **Challenge:** Explore adding a trendline using `abline(lm(rating ~ release_year))` to see if there's a general trend in ratings over time.
#
# **Code Snippet:**
#
# ```r
# # Step 1: Load data (replace or create a sample dataset)
# # ... code for loading or creating data
#
# # Step 2: Plot the scatter
# plot(release_year, rating, type = "p", main = "Movie Ratings Over Time",
#      xlab = "Release Year", ylab = "Rating", col = genre, alpha = 0.5)
#
# # Step 3: Challenge (add trendline)
# # ... code for abline(lm(...))
#
# # Optional: Add a legend if genre colors are used
# # ... code for legend using legend()
# ```

# %% [markdown]
# **Exercise 3: Medium - Plant Growth Tracking (Scatter Plot)**
#
# **Objective:** Monitor the growth of your plants by plotting height or diameter over time.
#
# **Instructions:**
#
# 1. **Create data:**
#
#    ```r
#    # Replace with your plant type, measurement days, and size values
#    plant_type <- "Sunflower"  # Specify plant type for customization
#    measurement_days <- c(7, 14, 21, 28, 35, 42)  # Days since planting
#    plant_size <- c(5, 8, 12, 17, 21, 25)  # Height or diameter measurements
#
#    # Optional: Create different point shapes based on plant type
#    pch <- ifelse(plant_type == "Sunflower", 16, 17)  # Use 16 for sunflowers, 17 for others
#    ```
#
# 2. **Plot the scatter:**
#
#    ```r
#    plot(measurement_days, plant_size, type = "p", pch = pch,
#         main = paste0(plant_type, " Growth Progress"),
#         xlab = "Days Since Planting", ylab = "Size (cm)")
#    ```
#
# 3. **Customize the graph:**
#
#    ```r
#    # Add title, axis labels, and adjust point shape based on plant type
#    title(main = paste0(plant_type, " Growth Progress"), xlab = "Days Since Planting", ylab = "Size (cm)")
#    ```
#
# 4. **Challenge (optional):**
#
#    ```r
#    # Fit a growth curve using nls() (requires curve fitting knowledge)
#    # ... code for fitting and adding the curve
#
#    # Add a legend if different point shapes are used
#    # ... code for legend using legend()
#    ```
#
# **Explanation:**
#
# - Step 1: Create data vectors with your actual plant type, measurement days, and size values. The optional `pch` vector assigns different point shapes based on plant type.
# - Step 2: Plot the scatter with `plot()` using the `type = "p"` argument for points. Customize the main title and axis labels using `main` and `xlab/ylab`, respectively.
# - Step 3: Further customize by adding `pch` for point shapes and adjusting the main title.
# - Step 4 (optional): This challenge requires knowledge of curve fitting with `nls()`. Once you fit a growth curve, add it to the plot and consider adding a legend if using different point shapes.
#
# Remember to replace the data and customize the plot according to your specific plants and preferences.

# %% [markdown]
# #Solutions to Exercises for Scatter Plot

# %% [markdown]
# ## Solutions and Explanations for Exercises 1-3:
#
# **Exercise 1: Easy - Your Sleep Patterns (Scatter Plot)**
#
# **Solution:**
#
# ```r
# # Step 1: Create data (replace with your values)
# days <- c("Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun")
# sleep_durations <- c(7.5, 6.8, 8.0, 7.2, 6.5, 8.8, 9.0)
#
# # Step 2: Plot the scatter and customize
# plot(days, sleep_durations, type = "p", main = "My Weekly Sleep",
#      xlab = "Day", ylab = "Sleep Duration (hours)", col = c("blue", "orange")[days %in% c("Mon", "Tue", "Wed", "Thu", "Fri")])
#
# # Step 3: Challenge (experiment with pch and cex)
# # Add circles (pch = 16) and slightly increase size (cex = 1.2)
# points(days, sleep_durations, type = "p", pch = 16, cex = 1.2)
#
# # Optional: Add a legend if many point shapes are used
# legend("topright", c("Weekdays", "Weekend"), col = c("blue", "orange"), pch = c(1, 16))
# ```
#
# **Explanation:**
#
# - Step 1 creates data vectors for days and sleep durations.
# - Step 2 plots the scatter with colors assigned based on weekdays/weekend using `col` and indexing.
# - The challenge adds circles (`pch = 16`) and increases point size (`cex = 1.2`).
# - The optional legend clarifies the color-coding.
#
# **Exercise 2: Easy - Comparing Movie Ratings (Scatter Plot)**
#
# **Solution:**
#
# ```r
# # Step 1: Load data (replace or create a sample dataset)
# # ... code for loading or creating data (assume a DataFrame named movies)
#
# # Step 2: Plot the scatter and customize
# plot(release_year, rating, type = "p", main = "Movie Ratings Over Time",
#      xlab = "Release Year", ylab = "Rating", col = genre, alpha = 0.5)
#
# # Step 3: Challenge (add trendline)
# # Fit a linear model and add the line
# abline(lm(rating ~ release_year), col = "gray", lwd = 0.5)
#
# # Optional: Add a legend if genre colors are used
# legend("topleft", c("Action", "Comedy", "Drama", "Sci-Fi"),
#        col = c("red", "orange", "blue", "purple"), alpha = 0.5)
# ```
#
# **Explanation:**
#
# - Step 1 assumes you have movie data with "release_year" and "rating" columns.
# - Step 2 plots the scatter with different colors for genres and transparency using `alpha`.
# - The challenge adds a gray trendline using `abline(lm(...))`.
# - The optional legend explains the genre colors.
#
# **Exercise 3: Medium - Plant Growth Tracking (Scatter Plot)**
#
# **Solution:**
#
# ```r
# # Step 1: Create data (replace with your measurements)
# measurement_days <- c(7, 14, 21, 28, 35, 42)
# plant_size <- c(5, 8, 12, 17, 21, 25)
#
# # Step 2: Plot the scatter and customize
# plot(measurement_days, plant_size, type = "p", pch = 16,  # Use circles for sunflowers
#      main = "Sunflower Growth Progress",
#      xlab = "Days Since Planting", ylab = "Height (cm)")
#
# # Step 3: Challenge (optional)
# # ... code for fitting and adding a growth curve (requires curve fitting knowledge)
#
# # Add a legend if different point shapes are used
# # ... code for legend using legend()
# ```
#
# **Explanation:**
#
# - Step 1 creates data vectors for measurement days and plant size.
# - Step 2 plots the scatter with circles (`pch = 16`) and customizes the title and labels.
# - The challenge (optional) involves curve fitting, which requires more advanced knowledge.
# - The legend (optional) would be relevant if using different point shapes for various plant types.
#
# Remember to replace the sample data with your actual values and experiment with different customizations to make the plots informative and visually appealing.

# %% [markdown]
# #solution to 1st exercise

# %% [markdown]
# #4. Pie Charts

# %% [markdown]
# R Pie Charts
# ------------
#
# * * *
#
# Pie Charts
# ----------
#
# A pie chart is a circular graphical view of data.
#
# Use the `pie()` function to draw pie charts:
#
# Let's break down the provided R code snippet step by step:
#
# ```r
# # Example R code: Creating a pie chart
# # We'll use the pie() function to create a simple pie chart
#
# # Create a vector of values representing the sizes of pie slices
# x <- c(10, 20, 30, 40)
#
# # Display the pie chart using the pie() function
# pie(x)
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Vector (`x`)**:
#    - We define a numeric vector called `x`.
#    - The vector contains the values `(10, 20, 30, 40)`.
#
# 2. **Plotting the Pie Chart (`pie(x)`)**:
#    - The `pie()` function creates a pie chart.
#    - We pass the vector `x` as input to the function.
#    - The resulting pie chart displays slices corresponding to the proportions `(10%, 20%, 30%, 40%)`.
#
# The pie chart visually represents the distribution of values in the vector `x`. Each slice represents a portion of the whole, and the size of each slice corresponds to the value in the vector. 🥧📊
#
# For more details on creating pie charts in R, you can explore additional resources such as [R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r).

# %%
# Example R code: Creating a pie chart
# We'll use the pie() function to create a simple pie chart

# Create a vector of values representing the sizes of pie slices
x <- c(10, 20, 30, 40)

# Display the pie chart using the pie() function
pie(x)
# Out:
# plot without title

# %% [markdown]
# #### Example Explained
#
# As you can see the pie chart draws one pie for each value in the vector (in this case 10, 20, 30, 40).
#
# By default, the plotting of the first pie starts from the x-axis and move **counterclockwise**.
#
# **Note:** The size of each pie is determined by comparing the value with all the other values, by using this formula:
#
# The value divided by the sum of all values: `x/sum(x)`
#
# * * *

# %% [markdown]
# Start Angle
# -----------
#
# You can change the start angle of the pie chart with the `init.angle` parameter.
#
# The value of `init.angle` is defined with angle in degrees, where default angle is 0.
#
# ### Example
#
# Start the first pie at 90 degrees:
#
# ```r
# # Example R code: Creating a customized pie chart
# # We'll use the pie() function to create a pie chart with a specific starting angle
#
# # Create a vector of values representing the sizes of pie slices
# x <- c(10, 20, 30, 40)
#
# # Display the pie chart using the pie() function
# # The 'init.angle' argument sets the starting angle to 90 degrees (top of the circle)
# pie(x, init.angle = 90)
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Vector (`x`)**:
#    - We define a numeric vector called `x`.
#    - The vector contains the values `(10, 20, 30, 40)`.
#
# 2. **Plotting the Pie Chart (`pie(x, init.angle = 90)`)**:
#    - The `pie()` function creates a pie chart.
#    - We pass the vector `x` as input to the function.
#    - The `init.angle = 90` argument sets the starting angle of the first slice to 90 degrees (which corresponds to the top of the circle).
#    - The resulting pie chart displays slices corresponding to the proportions `(10%, 20%, 30%, 40%)`.
#
# The customized pie chart visually represents the distribution of values in the vector `x`. Each slice represents a portion of the whole, and the starting angle determines the orientation of the first slice. 🥧📊
#
# For more details on creating pie charts in R, you can explore additional resources such as [R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r) .
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_pie_angle.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_pie_start_angle)
#
# * * *

# %%
# Example R code: Creating a customized pie chart
# We'll use the pie() function to create a pie chart with a specific starting angle

# Create a vector of values representing the sizes of pie slices
x <- c(10, 20, 30, 40)

# Display the pie chart using the pie() function
# The 'init.angle' argument sets the starting angle to 90 degrees (top of the circle)
pie(x, init.angle = 90)
# Out:
# plot without title

# %% [markdown]
# * * *
#
# Labels and Header
# -----------------
#
# Use the `label` parameter to add a label to the pie chart, and use the `main` parameter to add a header:
#
# ### Example
#
# ```r
# # Example R code: Creating a pie chart with labels
# # We'll use the pie() function to create a pie chart with custom labels
#
# # Create a vector of values representing the sizes of pie slices
# x <- c(10, 20, 30, 40)
#
# # Create a vector of labels for each slice
# mylabel <- c("Apples", "Bananas", "Cherries", "Dates")
#
# # Display the pie chart using the pie() function
# # The 'label' argument specifies the custom labels for each slice
# # The 'main' argument sets the title of the pie chart
# pie(x, label = mylabel, main = "Fruits")
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Vector (`x`)**:
#    - We define a numeric vector called `x`.
#    - The vector contains the values `(10, 20, 30, 40)`.
#
# 2. **Creating a Vector of Labels (`mylabel`)**:
#    - We define a character vector called `mylabel`.
#    - The vector contains the labels `"Apples"`, `"Bananas"`, `"Cherries"`, and `"Dates"` corresponding to each slice in the pie chart.
#
# 3. **Plotting the Pie Chart (`pie(x, label = mylabel, main = "Fruits")`)**:
#    - The `pie()` function creates a pie chart.
#    - We pass the vector `x` as input to the function.
#    - The `label` argument specifies the custom labels for each slice (from `mylabel`).
#    - The `main` argument sets the title of the pie chart to "Fruits".
#
# The resulting pie chart visually represents the distribution of fruit types (Apples, Bananas, Cherries, and Dates) based on the given proportions. Each slice corresponds to a specific fruit type. 🥧🍎🍌🍒📊
#
# For more details on creating pie charts in R, you can explore additional resources such as [R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r)..
#
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_pie_label.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_pie_labels)
#
# * * *

# %%
# Example R code: Creating a pie chart with labels
# We'll use the pie() function to create a pie chart with custom labels

# Create a vector of values representing the sizes of pie slices
x <- c(10, 20, 30, 40)

# Create a vector of labels for each slice
mylabel <- c("Apples", "Bananas", "Cherries", "Dates")

# Display the pie chart using the pie() function
# The 'label' argument specifies the custom labels for each slice
# The 'main' argument sets the title of the pie chart
pie(x, label = mylabel, main = "Fruits")
# Out:
# Plot with title “Fruits”

# %% [markdown]
# Colors
# ------
#
# You can add a color to each pie with the `col` parameter:
#
# ### Example
#
# ```r
# # Example R code: Creating a customized pie chart with colors
#
# # Create a vector of values representing the sizes of pie slices
# x <- c(10, 20, 30, 40)
#
# # Create a vector of labels for each slice
# mylabel <- c("Apples", "Bananas", "Cherries", "Dates")
#
# # Create a vector of colors for each slice
# colors <- c("blue", "yellow", "green", "black")
#
# # Display the pie chart using the pie() function
# # The 'label' argument specifies the custom labels for each slice
# # The 'main' argument sets the title of the pie chart
# # The 'col' argument sets the colors for each slice
# pie(x, label = mylabel, main = "Fruits", col = colors)
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Vector (`x`)**:
#    - We define a numeric vector called `x`.
#    - The vector contains the values `(10, 20, 30, 40)`.
#
# 2. **Creating a Vector of Labels (`mylabel`)**:
#    - We define a character vector called `mylabel`.
#    - The vector contains the labels `"Apples"`, `"Bananas"`, `"Cherries"`, and `"Dates"` corresponding to each slice in the pie chart.
#
# 3. **Creating a Vector of Colors (`colors`)**:
#    - We define a character vector called `colors`.
#    - The vector contains color names corresponding to each slice in the pie chart.
#
# 4. **Plotting the Pie Chart (`pie(x, label = mylabel, main = "Fruits", col = colors)`)**:
#    - The `pie()` function creates a pie chart.
#    - We pass the vector `x` as input to the function.
#    - The `label` argument specifies the custom labels for each slice.
#    - The `main` argument sets the title of the pie chart.
#    - The `col` argument sets the colors for each slice.
#
# The resulting customized pie chart visually represents the distribution of fruit types (Apples, Bananas, Cherries, and Dates) based on the given proportions, with each slice having a specific color. 🥧🍎🍌🍒📊
#
# For more details on creating pie charts in R, you can explore additional resources such as [R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r).
#
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_pie_col.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_pie_col)
#
# * * *

# %%
# Example R code: Creating a customized pie chart with colors

# Create a vector of values representing the sizes of pie slices
x <- c(10, 20, 30, 40)

# Create a vector of labels for each slice
mylabel <- c("Apples", "Bananas", "Cherries", "Dates")

# Create a vector of colors for each slice
colors <- c("blue", "yellow", "green", "black")

# Display the pie chart using the pie() function
# The 'label' argument specifies the custom labels for each slice
# The 'main' argument sets the title of the pie chart
# The 'col' argument sets the colors for each slice
pie(x, label = mylabel, main = "Fruits", col = colors)
# Out:
# Plot with title “Fruits”

# %% [markdown]
# Legend
# ------
#
# To add a list of explanation for each pie, use the `legend()` function:
#
# ### Example
#
# ```r
# # Example R code: Creating a customized pie chart with colors and a legend
#
# # Create a vector of labels for each slice
# mylabel <- c("Apples", "Bananas", "Cherries", "Dates")
#
# # Create a vector of colors for each slice
# colors <- c("blue", "yellow", "green", "black")
#
# # Display the pie chart using the pie() function
# # The 'label' argument specifies the custom labels for each slice
# # The 'main' argument sets the title of the pie chart
# # The 'col' argument sets the colors for each slice
# pie(x, label = mylabel, main = "Pie Chart", col = colors)
#
# # Display the explanation box (legend) in the bottom-right corner
# legend("bottomright", mylabel, fill = colors)
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Vector of Labels (`mylabel`)**:
#    - We define a character vector called `mylabel`.
#    - The vector contains the labels `"Apples"`, `"Bananas"`, `"Cherries"`, and `"Dates"` corresponding to each slice in the pie chart.
#
# 2. **Creating a Vector of Colors (`colors`)**:
#    - We define a character vector called `colors`.
#    - The vector contains color names corresponding to each slice in the pie chart.
#
# 3. **Plotting the Pie Chart (`pie(x, label = mylabel, main = "Pie Chart", col = colors)`)**:
#    - The `pie()` function creates a pie chart.
#    - We pass the vector `x` as input to the function.
#    - The `label` argument specifies the custom labels for each slice.
#    - The `main` argument sets the title of the pie chart.
#    - The `col` argument sets the colors for each slice.
#
# 4. **Adding a Legend (`legend("bottomright", mylabel, fill = colors)`)**:
#    - The `legend()` function adds a legend to the plot.
#    - We position the legend in the bottom-right corner.
#    - The legend displays the labels from `mylabel` along with their corresponding colors.
#
# The resulting customized pie chart visually represents the distribution of fruit types (Apples, Bananas, Cherries, and Dates) based on the given proportions, with each slice having a specific color and a legend explaining the labels. 🥧🍎🍌🍒📊
#
# For more details on creating pie charts in R, you can explore additional resources such as [R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r) .
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_pie_legend.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_pie_legend)
#
# The legend can be positioned as either:
#
# `bottomright`, `bottom`, `bottomleft`, `left`, `topleft`, `top`, `topright`, `right`, `center`

# %% [markdown]
# #Exercises fro Pie Charts

# %% [markdown]
# **Exercise 1: Easy - Favorite Pizza Toppings (Pie Chart)**
#
# **Objective:** Create a pie chart showing your favorite pizza toppings and their proportions.
#
# **Instructions:**
#
# 1. **Create data:**
#    - Make a vector named `toppings` with your favorite toppings (e.g., "Pepperoni", "Mushrooms", "Olives").
#    - Create another vector named `percentages` to represent the approximate percentage you like each topping (0-100%).
# 2. **Plot the pie chart:**
#    - Use `pie(percentages, labels = toppings, main = "My Favorite Pizza Toppings")` to generate the pie chart.
# 3. **Customize the graph:**
#    - Add colors to each topping using `col = c("red", "orange", "green", ...)`.
#    - Consider adding a legend using `legend(..., col = col, fill = col)` to explain the colors.
#
# **Code Snippet:**
#
# ```r
# # Step 1: Create data (replace with your toppings and percentages)
# toppings <- c("Pepperoni", "Mushrooms", "Olives", "Onions")
# percentages <- c(50, 25, 15, 10)
#
# # Step 2: Plot the pie chart
# pie(percentages, labels = toppings, main = "My Favorite Pizza Toppings")
#
# # Step 3: Customize the graph (optional)
# # ... code for col and legend customization
# ```
#
# **Challenge:** Experiment with different color schemes and legend placements to enhance the visual appeal.
#
# **Exercise 2: Easy - Comparing Sleep Quality by Day (Pie Chart)**
#
# **Objective:** Compare your sleep quality across weekdays and weekends using two pie charts.
#
# **Instructions:**
#
# 1. **Create data:**
#    - Make a vector named `days` with categories like "Weekday" and "Weekend".
#    - Create another vector named `sleep_scores` with average sleep quality scores (0-10) for each category.
# 2. **Plot the first pie chart:**
#    - Use `pie(sleep_scores[days == "Weekday"], labels = c("Weekday Sleep"), main = "Weekday Sleep Quality")` for weekdays.
# 3. **Plot the second pie chart:**
#    - Replace "Weekday" with "Weekend" in the previous code for the weekend chart.
#    - Adjust the main title and labels accordingly.
# 4. **Combine the charts (optional):**
#    - Use `layout(matrix(1:2, 1, 2))` to create a 1x2 grid for charts.
#    - Call your pie chart code within each cell of the grid.
#
# **Code Snippet:**
#
# ```r
# # Step 1: Create data (replace with your values)
# days <- c("Weekday", "Weekday", "Weekday", "Weekday", "Weekday", "Weekend", "Weekend")
# sleep_scores <- c(7, 6, 8, 8, 7, 9, 9)
#
# # Step 2: Plot the first pie chart
# pie(sleep_scores[days == "Weekday"], labels = c("Weekday Sleep"), main = "Weekday Sleep Quality")
#
# # Step 3: Plot the second pie chart (modify for weekend)
# # ... code for weekend pie chart
#
# # Step 4: Combine charts (optional)
# # ... code for layout() and chart placement
# ```
#
# **Challenge:** Consider adding different shading for weekdays and weekends in the first chart for easier comparison.

# %% [markdown]
# **Exercise 3: Medium - Movie Genre Preferences (Pie Chart)**
#
# **Objective:** Visualize your movie genre preferences by creating a pie chart with slices proportional to the number of movies watched in each genre.
#
# **Instructions:**
#
# 1. **Gather data:**
#
#    - Create a list or DataFrame containing movie titles and their genres. You can create a simple list like this:
#
#      ```r
#      movies <- list(
#        title = c("Interstellar", "The Big Lebowski", "Spirited Away", "Jurassic Park"),
#        genre = c("Sci-Fi", "Comedy", "Fantasy", "Adventure")
#      )
#      ```
#
#    - Alternatively, if you have movie data in a spreadsheet or file, load it using functions like `read.csv` or `read.xlsx`.
#
# 2. **Calculate proportions:**
#
#    - Count the occurrences of each genre in your data. You can use the `table()` function for this:
#
#      ```r
#      genre_counts <- table(movies$genre)
#      ```
#
#    - Divide the genre counts by the total number of movies to get proportions:
#
#      ```r
#      total_movies <- length(movies$genre)
#      proportions <- genre_counts / total_movies
#      ```
#
# 3. **Plot the pie chart:**
#
#    - Use `pie(proportions, labels = names(genre_counts), main = "My Movie Genre Preferences")` to create the pie chart.
#
# 4. **Customize the graph (optional):**
#
#    - Use relevant color palettes for genres using the `col` parameter. For example:
#
#      ```R
#      color_palette <- c("blue", "orange", "purple", "green")
#      pie(proportions, labels = names(genre_counts), main = "My Movie Genre Preferences",
#          col = color_palette[names(genre_counts)])
#      ```
#
#    - Add a legend or labels to clarify the colors using the `legend()` function with appropriate arguments.
#
# Remember to replace the sample data (`movies`) with your actual movie information and customize the plot according to your preferences. Don't hesitate to ask if you have any questions!

# %% [markdown]
# #Solutions for Pie Chart

# %% [markdown]
# ## Solutions and Explanations for Exercises 1-3 with Challenges:
#
# **Exercise 1: Easy - Favorite Pizza Toppings (Pie Chart)**
#
# **Solution:**
#
# ```r
# # Step 1: Create data (replace with your toppings and percentages)
# toppings <- c("Pepperoni", "Mushrooms", "Olives", "Onions")
# percentages <- c(50, 25, 15, 10)
#
# # Step 2: Plot the pie chart
# pie(percentages, labels = toppings, main = "My Favorite Pizza Toppings")
#
# # Step 3: Challenge (customize colors and legend)
# pie(percentages, labels = toppings, main = "My Favorite Pizza Toppings",
#     col = c("red", "orange", "green", "purple"))  # Use different colors
#
# # Add legend to explain colors
# legend("topright", toppings, col = c("red", "orange", "green", "purple"), fill = c("red", "orange", "green", "purple"))
# ```
#
# **Explanation:**
#
# - Step 1 creates data vectors for toppings and their percentages.
# - Step 2 plots the pie chart with labels.
# - The challenge adds different colors using `col` and a legend using `legend()` to explain them.
#
# **Challenge:** Experiment with other color palettes and legend positions (e.g., "bottomleft").
#
# **Exercise 2: Easy - Comparing Sleep Quality by Day (Pie Chart)**
#
# **Solution:**
#
# ```r
# # Step 1: Create data (replace with your values)
# days <- c("Weekday", "Weekday", "Weekday", "Weekday", "Weekday", "Weekend", "Weekend")
# sleep_scores <- c(7, 6, 8, 8, 7, 9, 9)
#
# # Step 2: Plot the first pie chart
# pie(sleep_scores[days == "Weekday"], labels = c("Weekday Sleep"), main = "Weekday Sleep Quality", col = c("lightblue", "lightgray")[1])  # Add shading
#
# # Step 3: Plot the second pie chart (modify for weekend)
# pie(sleep_scores[days == "Weekend"], labels = c("Weekend Sleep"), main = "Weekend Sleep Quality", col = c("lightblue", "lightgray")[2])
#
# # Step 4: Combine charts (optional)
# # ... use layout() and call pie chart code within each cell
# ```
#
# **Explanation:**
#
# - Step 1 creates data for days and sleep scores.
# - Step 2 and 3 plot separate pie charts for weekdays and weekends, adding subtle shading using `col` for visual comparison.
# - The optional Step 4 demonstrates combining charts using `layout()`.
#
# **Challenge:** Calculate average sleep scores for each day type and display them in the chart titles.
#
# **Exercise 3: Medium - Movie Genre Preferences (Pie Chart)**
#
# **Solution:**
#
# ```r
# # Step 1: Gather data (replace with your list or DataFrame)
# movies <- list(
#   title = c("Interstellar", "The Big Lebowski", "Spirited Away", "Jurassic Park", "The Shawshank Redemption"),
#   genre = c("Sci-Fi", "Comedy", "Fantasy", "Adventure", "Drama")
# )
#
# # Step 2: Calculate proportions
# genre_counts <- table(movies$genre)
# total_movies <- length(movies$genre)
# proportions <- genre_counts / total_movies
#
# # Step 3: Plot the pie chart
# pie(proportions, labels = names(genre_counts), main = "My Movie Genre Preferences",
#     col = c("blue", "orange", "purple", "green", "gray"))  # Use relevant colors
#
# # Step 4: Challenge (add legend)
# legend("topright", names(genre_counts), col = c("blue", "orange", "purple", "green", "gray"), fill = c("blue", "orange", "purple", "green", "gray"))
# ```
#
# **Explanation:**
#
# - Step 1 creates sample movie data (replace with your own).
# - Step 2 calculates genre counts, total movies, and proportions.
# - Step 3 plots the pie chart with relevant colors based on genres.
# - The challenge adds a legend using `legend()` to clarify the color-genre mapping.
#
# **Challenge:** Explore color palettes specific to movie genres (e.g., horror: dark red, comedy: yellow).
#
# Remember to replace the sample data with your actual information and customize the plots based on your preferences. Feel free to ask if you have any questions!

# %% [markdown]
# # 05 - Bar Charts

# %% [markdown]
# R Bar Charts
# ------------
#
# * * *
#
# Bar Charts
# ----------
#
# A bar chart uses rectangular bars to visualize data. Bar charts can be displayed horizontally or vertically. The height or length of the bars are proportional to the values they represent.
#
# Use the `barplot()` function to draw a vertical bar chart:
#
# ### Example
#
#
# ```r
# # Example R code: Creating a bar plot
#
# # Create a vector of x-axis labels
# x <- c("A", "B", "C", "D")
#
# # Create a vector of y-axis values
# y <- c(2, 4, 6, 8)
#
# # Display the bar plot using the barplot() function
# barplot(y, names.arg = x)
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Vector of X-Axis Labels (`x`)**:
#    - We define a character vector called `x`.
#    - The vector contains the labels `"A"`, `"B"`, `"C"`, and `"D"` corresponding to the x-axis categories.
#
# 2. **Creating a Vector of Y-Axis Values (`y`)**:
#    - We define a numeric vector called `y`.
#    - The vector contains the values `(2, 4, 6, 8)` corresponding to the heights of the bars.
#
# 3. **Plotting the Bar Chart (`barplot(y, names.arg = x)`)**:
#    - The `barplot()` function creates a bar plot.
#    - We pass the vector `y` as input to the function.
#    - The `names.arg` argument specifies the labels for the x-axis categories.
#
# The resulting bar plot visually represents the data with bars corresponding to each category (A, B, C, D) and their respective heights. 📊🔍
#
# For more details on creating bar plots in R, you can explore additional resources such as [R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r) ¹.
#
# (1) Barplot in R (8 Examples) | How to Create Barchart & Bargraph in RStudio. https://statisticsglobe.com/barplot-in-r.
#
# (2) R - Bar Charts - GeeksforGeeks. https://www.geeksforgeeks.org/r-bar-charts/.
#
# (3) R Bar Plot (With Examples) - DataMentor. https://www.datamentor.io/r-programming/bar-plot.
#
# (4) R Bar Plot (with Examples) - Programiz. https://www.programiz.com/r/barplot.
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_bar.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_bar)
#
# #### Example Explained
#
# *   The `x` variable represents values in the x-axis (A,B,C,D)
# *   The `y` variable represents values in the y-axis (2,4,6,8)
# *   Then we use the `barplot()` function to create a bar chart of the values
# *   `names.arg` defines the names of each observation in the x-axis
#
# * * *

# %%
# Example R code: Creating a bar plot

# Create a vector of x-axis labels
x <- c("A", "B", "C", "D")

# Create a vector of y-axis values
y <- c(2, 4, 6, 8)

# Display the bar plot using the barplot() function
barplot(y, names.arg = x)
# Out:
# plot without title

# %% [markdown]
# Bar Color
# ---------
#
# Use the `col` parameter to change the color of the bars:
#
# ### Example
#
# ```r
# # Example R code: Creating a bar plot
#
# # Create a vector of x-axis labels
# x <- c("A", "B", "C", "D")
#
# # Create a vector of y-axis values
# y <- c(2, 4, 6, 8)
#
# # Display the bar plot using the barplot() function
# barplot(y, names.arg = x, col = "red")
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Vector of X-Axis Labels (`x`)**:
#    - We define a character vector called `x`.
#    - The vector contains the labels `"A"`, `"B"`, `"C"`, and `"D"` corresponding to the x-axis categories.
#
# 2. **Creating a Vector of Y-Axis Values (`y`)**:
#    - We define a numeric vector called `y`.
#    - The vector contains the values `(2, 4, 6, 8)` corresponding to the heights of the bars.
#
# 3. **Plotting the Bar Chart (`barplot(y, names.arg = x, col = "red")`)**:
#    - The `barplot()` function creates a bar plot.
#    - We pass the vector `y` as input to the function.
#    - The `names.arg` argument specifies the labels for the x-axis categories.
#    - The bars are displayed in red.
#
# The resulting bar plot visually represents the data with bars corresponding to each category (A, B, C, D) and their respective heights. 📊🔍
#
# For more details on creating bar plots in R, you can explore additional resources such as [R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r).
#
# Source:
# (1) Barplot in R (8 Examples) | How to Create Barchart & Bargraph in RStudio. https://statisticsglobe.com/barplot-in-r.
# (2) R - Bar Charts - GeeksforGeeks. https://www.geeksforgeeks.org/r-bar-charts/.
# (3) R Bar Plot (With Examples) - DataMentor. https://www.datamentor.io/r-programming/bar-plot.
# (4) R Bar Plot (with Examples) - Programiz. https://www.programiz.com/r/barplot.
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_bar_col.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_bar_col)
#
# * * *

# %%
# Example R code: Creating a bar plot

# Create a vector of x-axis labels
x <- c("A", "B", "C", "D")

# Create a vector of y-axis values
y <- c(2, 4, 6, 8)

# Display the bar plot using the barplot() function
barplot(y, names.arg = x, col = "red")
# Out:
# plot without title

# %% [markdown]
# Density / Bar Texture
# ---------------------
#
# To change the bar texture, use the `density` parameter:
#
# ### Example
#
# ```r
# # Example R code: Creating a customized bar plot
#
# # Create a vector of x-axis labels
# x <- c("A", "B", "C", "D")
#
# # Create a vector of y-axis values
# y <- c(2, 4, 6, 8)
#
# # Display the bar plot using the barplot() function
# # The 'names.arg' argument specifies the labels for the x-axis categories
# # The 'density' argument sets the density of shading lines (optional)
# barplot(y, names.arg = x, density = 10)
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Vector of X-Axis Labels (`x`)**:
#    - We define a character vector called `x`.
#    - The vector contains the labels `"A"`, `"B"`, `"C"`, and `"D"` corresponding to the x-axis categories.
#
# 2. **Creating a Vector of Y-Axis Values (`y`)**:
#    - We define a numeric vector called `y`.
#    - The vector contains the values `(2, 4, 6, 8)` corresponding to the heights of the bars.
#
# 3. **Plotting the Bar Chart (`barplot(y, names.arg = x, density = 10)`)**:
#    - The `barplot()` function creates a bar plot.
#    - We pass the vector `y` as input to the function.
#    - The `names.arg` argument specifies the labels for the x-axis categories.
#    - The `density` argument sets the density of shading lines (optional).
#
# The resulting customized bar plot visually represents the data with bars corresponding to each category (A, B, C, D) and their respective heights. 📊🔍
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_bar_density.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_bar_density)
#
# * * *

# %%
# Example R code: Creating a customized bar plot

# Create a vector of x-axis labels
x <- c("A", "B", "C", "D")

# Create a vector of y-axis values
y <- c(2, 4, 6, 8)

# Display the bar plot using the barplot() function
# The 'names.arg' argument specifies the labels for the x-axis categories
# The 'density' argument sets the density of shading lines (optional)
barplot(y, names.arg = x, density = 10)
# Out:
# plot without title

# %% [markdown]
# * * *
#
# Bar Width
# ---------
#
# Use the `width` parameter to change the width of the bars:
#
# ### Example
#
# ```r
# # Example R code: Creating a customized bar plot
#
# # Create a vector of x-axis labels
# x <- c("A", "B", "C", "D")
#
# # Create a vector of y-axis values
# y <- c(2, 4, 6, 8)
#
# # Display the bar plot using the barplot() function
# # The 'names.arg' argument specifies the labels for the x-axis categories
# # The 'width' argument sets the width of each bar
# barplot(y, names.arg = x, width = c(1, 2, 3, 4))
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Vector of X-Axis Labels (`x`)**:
#    - We define a character vector called `x`.
#    - The vector contains the labels `"A"`, `"B"`, `"C"`, and `"D"` corresponding to the x-axis categories.
#
# 2. **Creating a Vector of Y-Axis Values (`y`)**:
#    - We define a numeric vector called `y`.
#    - The vector contains the values `(2, 4, 6, 8)` corresponding to the heights of the bars.
#
# 3. **Plotting the Bar Chart (`barplot(y, names.arg = x, width = c(1, 2, 3, 4))`)**:
#    - The `barplot()` function creates a bar plot.
#    - We pass the vector `y` as input to the function.
#    - The `names.arg` argument specifies the labels for the x-axis categories.
#    - The `width` argument sets the width of each bar.
#
# The resulting customized bar plot visually represents the data with bars corresponding to each category (A, B, C, D) and their respective heights. The bars have different widths based on the specified values in the `width` argument. 📊🔍
#
# For more details on creating bar plots in R, you can explore additional resources such as [R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r).
#
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_bar_width.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_bar_width)
#
# * * *

# %%
# Example R code: Creating a customized bar plot

# Create a vector of x-axis labels
x <- c("A", "B", "C", "D")

# Create a vector of y-axis values
y <- c(2, 4, 6, 8)

# Display the bar plot using the barplot() function
# The 'names.arg' argument specifies the labels for the x-axis categories
# The 'width' argument sets the width of each bar
barplot(y, names.arg = x, width = c(1, 2, 3, 4))
# Out:
# plot without title

# %% [markdown]
# Horizontal Bars
# ---------------
#
# If you want the bars to be displayed horizontally instead of vertically, use `horiz=TRUE`:
#
# ### Example
#
#
# ```r
# # Example R code: Creating a horizontal bar plot
#
# # Create a vector of x-axis labels
# x <- c("A", "B", "C", "D")
#
# # Create a vector of y-axis values
# y <- c(2, 4, 6, 8)
#
# # Display the horizontal bar plot using the barplot() function
# barplot(y, names.arg = x, horiz = TRUE)
# ```
#
# Here's what each part of the code does:
#
# 1. **Creating a Vector of X-Axis Labels (`x`)**:
#    - We define a character vector called `x`.
#    - The vector contains the labels `"A"`, `"B"`, `"C"`, and `"D"` corresponding to the x-axis categories.
#
# 2. **Creating a Vector of Y-Axis Values (`y`)**:
#    - We define a numeric vector called `y`.
#    - The vector contains the values `(2, 4, 6, 8)` corresponding to the heights of the bars.
#
# 3. **Plotting the Horizontal Bar Chart (`barplot(y, names.arg = x, horiz = TRUE)`)**:
#    - The `barplot()` function creates a bar plot.
#    - We pass the vector `y` as input to the function.
#    - The `names.arg` argument specifies the labels for the x-axis categories.
#    - The `horiz = TRUE` argument creates a horizontal bar plot.
#
# The resulting horizontal bar plot visually represents the data with bars corresponding to each category (A, B, C, D) and their respective heights. 📊🔍
#
# For more details on creating bar plots in R, you can explore additional resources such as [R Basics Cheat Sheet](https://www.datacamp.com/cheat-sheet/getting-started-r).
#
# Result:
#
# ![](https://i3.wp.com/www.w3schools.com/r/r_bar_hor.png)
#
# [Try it Yourself »](https://www.w3schools.com/r/tryr.asp?filename=demo_graph_bar_hor)

# %%
# Example R code: Creating a horizontal bar plot

# Create a vector of x-axis labels
x <- c("A", "B", "C", "D")

# Create a vector of y-axis values
y <- c(2, 4, 6, 8)

# Display the horizontal bar plot using the barplot() function
barplot(y, names.arg = x, horiz = TRUE)
# Out:
# plot without title

# %% [markdown]
# # 5-Exercises for Bar Charts

# %% [markdown]
# **Exercise 1: Super Easy - Favorite Video Game Genres (Bar Chart)**
#
# **Objective:** Visualize your favorite video game genres and their playtime using a colorful bar chart.
#
# **Instructions:**
#
# 1. **Create data:**
#    - Make a vector named `genres` containing your favorite video game genres (e.g., "Action", "RPG", "Puzzle").
#    - Create another vector named `hours_played` with approximate hours spent on each genre.
# 2. **Plot the bar chart:**
#    - Use `barplot(hours_played, names.arg = genres, col = c("red", "orange", "green", ...))` to generate the chart.
#    - Customize the main title and x-axis label using `main = "My Favorite Game Genres (Hours Played)"` and `xlab = "Genre"`.
# 3. **Challenge (experiment with bar width and texture):**
#    - Use the `width` parameter to adjust bar widths based on playtime (e.g., `width = hours_played * 0.2`).
#    - Experiment with different `density` values (1-20) to create varied bar textures.
#
# **Code Snippet:**
#
# ```r
# # Step 1: Create data (replace with your genres and hours played)
# genres <- c("Action", "RPG", "Puzzle", "Simulation")
# hours_played <- c(20, 15, 10, 5)
#
# # Step 2: Plot the bar chart
# barplot(hours_played, names.arg = genres, col = c("red", "orange", "green", "blue"),
#         main = "My Favorite Game Genres (Hours Played)", xlab = "Genre")
#
# # Step 3: Challenge (optional)
# # ... code for width and density customization
# ```
#
# **Exercise 2: Easy - Comparing Sleep Quality by Day (Horizontal Bar Chart)**
#
# **Objective:** Compare your sleep quality across weekdays and weekends using a horizontal bar chart.
#
# **Instructions:**
#
# 1. **Create data:**
#    - Make a vector named `days` with categories like "Weekday" and "Weekend".
#    - Create another vector named `sleep_scores` with average sleep quality scores (0-10) for each category.
# 2. **Plot the horizontal bar chart:**
#    - Use `barplot(sleep_scores, names.arg = days, horiz = TRUE, col = c("lightblue", "lightgray"))` to generate the chart.
#    - Add labels for the y-axis using `ylab = "Sleep Quality Score"`.
# 3. **Challenge (add data labels and legend):**
#    - Use `text()` to add data labels directly above each bar (e.g., `text(sleep_scores + 0.2, sleep_scores, pos = 2)`)
#    - Consider adding a legend using `legend()` to explain the bar colors.
#
# **Code Snippet:**
#
# ```r
# # Step 1: Create data (replace with your values)
# days <- c("Weekday", "Weekday", "Weekday", "Weekday", "Weekday", "Weekend", "Weekend")
# sleep_scores <- c(7, 6, 8, 8, 7, 9, 9)
#
# # Step 2: Plot the horizontal bar chart
# barplot(sleep_scores, names.arg = days, horiz = TRUE, col = c("lightblue", "lightgray"),
#         ylab = "Sleep Quality Score")
#
# # Step 3: Challenge (optional)
# # ... code for data labels and legend
# ```

# %% [markdown]
# **Exercise 3: Medium - Movie Rating Distribution (Stacked Bar Chart)**
#
# **Objective:** Visualize the distribution of movie ratings (1-5) for different genres using a stacked bar chart.
#
# **Instructions:**
#
# 1. **Gather data:**
#
#    - Create a list or DataFrame containing movie titles, genres, and ratings. You can create a simple list like this:
#
#      ```R
#      movies <- list(
#        title = c("Interstellar", "The Big Lebowski", "Spirited Away", "Jurassic Park"),
#        genre = c("Sci-Fi", "Comedy", "Fantasy", "Adventure"),
#        rating = c(5, 4, 5, 4)
#      )
#      ```
#
#    - Alternatively, if you have movie data in a spreadsheet or file, load it using functions like `read.csv` or `read.xlsx`.
#
# 2. **Prepare data for stacked bars:**
#
#    - Use `table(movies$genre, movies$rating)` to count the occurrences of each genre-rating combination. This creates a table summarizing the data.
#
# 3. **Plot the stacked bar chart:**
#
#    - Use `barplot(table(movies$genre, movies$rating), col = c("red", "orange", "yellow", "green", "blue"))` to generate the stacked bar chart.
#      - Customize the title and labels using `main = "Movie Rating Distribution by Genre"`, `xlab = "Genre"`, and `ylab = "Number of Movies"`.
#
# 4. **Challenge (add data labels and legend):**
#
#    - Use `text()` to add data labels on top of each bar segment (e.g., `text(rowSums(table(movies$genre, movies$rating)), ...)`).
#    - Consider adding a legend using `legend()` to explain the genre-color mapping.
#
# **Remember to replace the sample data (`movies`) with your actual movie information and customize the plot according to your preferences.**

# %% [markdown]
# #5 - Solutions to Bar Chart Exercises

# %% [markdown]
# ## Solutions and Explanations for Exercises 1-3 with Challenges:
#
# **Exercise 1: Easy - Favorite Video Game Genres (Bar Chart)**
#
# **Solution:**
#
# ```r
# # Step 1: Create data (replace with your genres and hours played)
# genres <- c("Action", "RPG", "Puzzle", "Simulation")
# hours_played <- c(20, 15, 10, 5)
#
# # Step 2: Plot the bar chart
# barplot(hours_played, names.arg = genres, col = c("red", "orange", "green", "blue"),
#         main = "My Favorite Game Genres (Hours Played)", xlab = "Genre")
#
# # Step 3: Challenge (customize bar width and texture)
# # Adjust bar widths based on playtime (example)
# barplot(hours_played, names.arg = genres, col = c("red", "orange", "green", "blue"),
#         width = hours_played * 0.2, main = "My Favorite Game Genres (Hours Played)", xlab = "Genre")
#
# # Experiment with density values (1-20) for texture (example)
# barplot(hours_played, names.arg = genres, col = c("red", "orange", "green", "blue"),
#         density = 5, main = "My Favorite Game Genres (Hours Played)", xlab = "Genre")
# ```
#
# **Explanation:**
#
# - Step 1 creates data vectors for genres and hours played.
# - Step 2 plots the bar chart with colors, title, and x-axis label.
# - The challenge demonstrates customizing bar width and experimenting with bar texture using `width` and `density` parameters.
#
# **Challenge:** Explore different color palettes and density values to visually distinguish genres.
#
# **Exercise 2: Easy - Comparing Sleep Quality by Day (Horizontal Bar Chart)**
#
# **Solution:**
#
# ```r
# # Step 1: Create data (replace with your values)
# days <- c("Weekday", "Weekday", "Weekday", "Weekday", "Weekday", "Weekend", "Weekend")
# sleep_scores <- c(7, 6, 8, 8, 7, 9, 9)
#
# # Step 2: Plot the horizontal bar chart
# barplot(sleep_scores, names.arg = days, horiz = TRUE, col = c("lightblue", "lightgray"),
#         ylab = "Sleep Quality Score")
#
# # Step 3: Challenge (add data labels and legend)
# # Add data labels above each bar
# barplot(sleep_scores, names.arg = days, horiz = TRUE, col = c("lightblue", "lightgray"),
#         ylab = "Sleep Quality Score")
# text(sleep_scores + 0.2, sleep_scores, pos = 2)
#
# # Add a legend to explain bar colors
# barplot(sleep_scores, names.arg = days, horiz = TRUE, col = c("lightblue", "lightgray"),
#         ylab = "Sleep Quality Score")
# legend("topright", c("Weekday", "Weekend"), col = c("lightblue", "lightgray"), fill = c("lightblue", "lightgray"))
# ```
#
# **Explanation:**
#
# - Step 1 creates data for days and sleep scores.
# - Step 2 plots the horizontal bar chart with colors, y-axis label.
# - The challenge adds data labels using `text()` and an explanatory legend using `legend()`.
#
# **Challenge:** Calculate average sleep scores for each day type and display them in data labels.
#
# **Exercise 3: Medium - Movie Rating Distribution (Stacked Bar Chart)**
#
# **Solution:**
#
# ```R
# # Step 1: Gather data (replace with your movie list)
# movies <- list(
#   title = c("Interstellar", "The Big Lebowski", "Spirited Away", "Jurassic Park"),
#   genre = c("Sci-Fi", "Comedy", "Fantasy", "Adventure"),
#   rating = c(5, 4, 5, 4)
# )
#
# # Step 2: Prepare data for stacked bars
# genre_rating_counts <- table(movies$genre, movies$rating)  # Count occurrences of each genre-rating combination
#
# # Step 3: Plot the stacked bar chart
# barplot(genre_rating_counts, col = c("red", "orange", "yellow", "green", "blue"),
#         main = "Movie Rating Distribution by Genre", xlab = "Genre", ylab = "Number of Movies")
#
# # Step 4: Challenge (add data labels and legend)
# # Add data labels on top of each bar segment
# barplot(genre_rating_counts, col = c("red", "orange", "yellow", "green", "blue"),
#         main = "Movie Rating Distribution by Genre", xlab = "Genre", ylab = "Number of Movies")
# text(rowSums(genre_rating_counts), colMeans(genre_rating_counts) + 0.2, pos = 4, labels = genre_rating_counts, cex = 0.7)  # Add data labels with adjustments
#
# # Add a legend to explain bar colors
# legend("topright", names(genre_rating_counts), col = c("red", "orange", "yellow", "green", "blue"), fill = c("red", "orange", "yellow", "green", "blue"))
# ```
#
# **Explanation:**
#
# - Step 1 creates sample movie data (`movies`). Replace with your actual data.
# - Step 2 uses `table(movies$genre, movies$rating)` to count genre-rating occurrences.
# - Step 3 plots the stacked bar chart with colors, title, and axis labels.
# - The challenge demonstrates adding data labels using `text()` with adjustments for positioning and font size. It also adds a legend using `legend()`.
#
# **Remember to replace the sample data with your actual movie information and customize the plot according to your preferences.**

# %% [markdown]
# ##Solutions to Challenges
#
# **Exercise 1: Super Easy - Favorite Video Game Genres (Bar Chart)**
#
# **Challenge:** Explore different color palettes and density values to visually distinguish genres.
#
# **Solution:**
#
# ```r
# # Explore different color palettes
# barplot(hours_played, names.arg = genres, col = rainbow(length(genres)),
#         main = "My Favorite Game Genres (Hours Played)", xlab = "Genre")
#
# # Experiment with density values (1-20) for texture
# barplot(hours_played, names.arg = genres, col = c("red", "orange", "green", "blue"),
#         density = 10, main = "My Favorite Game Genres (Hours Played)", xlab = "Genre")
#
# # Combine different variations for more customization
# barplot(hours_played, names.arg = genres, col = rainbow(length(genres)),
#         density = 5, main = "My Favorite Game Genres (Hours Played)", xlab = "Genre")
# ```
#
# **Exercise 2: Easy - Comparing Sleep Quality by Day (Horizontal Bar Chart)**
#
# **Challenge:** Calculate average sleep scores for each day type and display them in data labels.
#
# **Solution:**
#
# ```r
# # Calculate average sleep scores per day type
# weekday_avg <- mean(sleep_scores[days == "Weekday"])
# weekend_avg <- mean(sleep_scores[days == "Weekend"])
#
# # Add data labels with average scores
# barplot(sleep_scores, names.arg = days, horiz = TRUE, col = c("lightblue", "lightgray"),
#         ylab = "Sleep Quality Score")
# text(sleep_scores + 0.2, sleep_scores, pos = 2)
# text(c(weekday_avg, weekend_avg), c(max(sleep_scores) + 0.2, min(sleep_scores) - 0.2),
#      pos = 4, labels = c(round(weekday_avg, 1), round(weekend_avg, 1)), cex = 0.7)  # Add average scores
#
# # Add a legend to explain bar colors
# barplot(sleep_scores, names.arg = days, horiz = TRUE, col = c("lightblue", "lightgray"),
#         ylab = "Sleep Quality Score")
# legend("topright", c("Weekday", "Weekend"), col = c("lightblue", "lightgray"), fill = c("lightblue", "lightgray"))
# ```
#
# **Exercise 3: Medium - Movie Rating Distribution (Stacked Bar Chart)**
#
# **Challenge:** Add data labels directly on top of each bar segment instead of below.
#
# **Solution:**
#
# ```R
# # ... previous code for steps 1-3
#
# # Add data labels directly on top of each bar segment
# barplot(genre_rating_counts, col = c("red", "orange", "yellow", "green", "blue"),
#         main = "Movie Rating Distribution by Genre", xlab = "Genre", ylab = "Number of Movies")
# text(rowSums(genre_rating_counts), colMeans(genre_rating_counts) + 0.2, pos = 4, labels = genre_rating_counts, cex = 0.7)
#
# # Modify data label positioning for better visibility
# barplot(genre_rating_counts, col = c("red", "orange", "yellow", "green", "blue"),
#         main = "Movie Rating Distribution by Genre", xlab = "Genre", ylab = "Number of Movies")
# text(rowSums(genre_rating_counts) / 2, genre_rating_counts, pos = 4, labels = genre_rating_counts, cex = 0.7)
#
# # ... legend code
# ```
#
# Remember to experiment with different values and approaches to customize the challenges according to your preferences and data!

# %% [markdown]
# #Working with `ggplot2`

# %% [markdown]
# **ggplot2** is a powerful and flexible **R package** for creating elegant data visualizations. Developed by **Hadley Wickham** in 2005, ggplot2 implements **Leland Wilkinson's Grammar of Graphics**, which provides a structured approach to creating graphs by breaking them down into semantic components such as scales and layers¹².
#
# Here are the key points about ggplot2:
#
# 1. **Declarative Approach**: With ggplot2, you provide the data, specify how to map variables to aesthetics (such as color or size), choose graphical primitives (like points or bars), and it takes care of the details. This declarative approach allows you to create complex visualizations with ease.
#
# 2. **Abstraction Layers**: ggplot2 allows you to add, remove, or alter components in a plot at a high level of abstraction. You start with `ggplot()`, supply a dataset and aesthetic mappings using `aes()`, and then add layers (e.g., `geom_point()` for scatter plots or `geom_histogram()` for histograms), scales, faceting specifications, and coordinate systems.
#
# 3. **Rich Ecosystem**: ggplot2 has been widely adopted and is one of the most popular R packages. While the core package remains stable, there's a rich ecosystem of extensions and customizations available from the community⁴.
#
# 4. **Learning Resources**:
#     - **R for Data Science**: Start with the Data Visualization and Graphics for communication chapters in "R for Data Science." It provides a systematic introduction to ggplot2.
#     - **Online Course**: Consider taking the "Data Visualization in R With ggplot2" course by Kara Woo.
#     - **Webinar**: Explore "Plotting Anything with ggplot2" by Thomas Lin Pedersen.
#     - **Book**: For practical solutions, "The R Graphics Cookbook" by Winston Chang offers recipes for common graphics problems.
#     - **Theory**: Dive deeper into the theoretical foundations of ggplot2 with "ggplot2: Elegant Graphics for Data Analysis."
#
# In summary, ggplot2 empowers you to create expressive and customizable visualizations using a consistent grammar of graphics. 📊🎨.
#
# **Sources:**
#
# (1) ggplot2 - Wikipedia. https://en.wikipedia.org/wiki/Ggplot2.
#
# (2) Best Introduction to GGPlot2 - Datanovia. https://www.datanovia.com/en/lessons/introduction-to-ggplot2/.
#
# (3) Create Elegant Data Visualisations Using the Grammar of Graphics • ggplot2. https://ggplot2.tidyverse.org/.
#
# (4) A ggplot2 tutorial for beginners - Sharp Sight. https://www.sharpsightlabs.com/blog/ggplot2-tutorial/.
#
# (5) ggplot2 package - RDocumentation. https://www.rdocumentation.org/packages/ggplot2/versions/3.4.4.
#
# (6) Data visualization with R and ggplot2 | the R Graph Gallery. https://r-graph-gallery.com/ggplot2-package.html.
#
# (7) undefined. https://exts.ggplot2.tidyverse.org/gallery/.
#
# (8) en.wikipedia.org. https://en.wikipedia.org/wiki/Ggplot2.

# %% [markdown]
# **1. Setting Up Google Colab:**
#
# - Open Google Colab: [https://colab.research.google.com/](https://colab.research.google.com/)
# - Click "New Notebook" and choose "Python 3" runtime (it works for both Python and R!).
#
# **2. Installing `ggplot2`:**
#
# - In the first code cell, type:
#
# ```python
# #in python environment
# !pip install ggplot2
# ```
#
# For R
# ```r
# install.packages("ggplot2")
# ```
#
# - Press "Run" (Shift+Enter).
#
#
# **Load the ggplot2 package**:
#    - After installing, load the package using the R function `library(ggplot2)`.
#
# Now you're all set to create beautiful visualizations using **ggplot2** in your Google Colab notebook! 📊🌟
#
#
#
# **3. Loading Dataset:**
#
# - You can upload your own data as a CSV file (click "Files" -> "Upload") or use built-in datasets like `mtcars`:
#
# ```r
# library(datasets)
# data(mtcars)
# ```
#
# **4. Basic ggplot2 Syntax:**
#
# - `ggplot(data, aes(x, y)) + geom_point()` is the foundation.
#     - `data`: Your data frame
#     - `aes(x, y)`: Defines what goes on the x and y axes
#     - `geom_point()`: Creates scatter points (change to `geom_bar()` for bars, etc.)
#
# **5. Example - Plotting MPG vs. Horsepower:**
#
# ```r
# ggplot(mtcars, aes(x = hp, y = mpg)) +
#   geom_point() +
#   labs(title = "MPG vs. Horsepower", x = "Horsepower", y = "MPG")
# ```
#
# - Run the code and see the plot in the output below!
#
# **6. Customization:**
#
# - Explore different geom functions (e.g., `geom_line()` for lines, `geom_bar()` for bars).
# - Change colors, add titles, adjust scales using arguments within `ggplot()`.
# - For more advanced customization, refer to ggplot2 documentation: [https://ggplot2.tidyverse.org/](https://ggplot2.tidyverse.org/)
#
# **Remember:**
#
# - Use comments (#) to explain your code.
# - Practice with different datasets and visualizations.
# - Explore ggplot2's vast capabilities to create informative and beautiful plots!
#
# This is just a starting point. With practice and exploration, you'll be creating amazing visualizations in no time!

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)

# %%
# You can upload your own data as a CSV file (click "Files" -> "Upload") or use built-in datasets like mtcars:
library(datasets)
data(mtcars)

# %%
# Basic ggplot2 Syntax:

# ggplot(data, aes(x, y)) + geom_point() is the foundation.
# data: Your data frame
# aes(x, y): Defines what goes on the x and y axes
# geom_point(): Creates scatter points (change to geom_bar() for bars, etc.)
# Example - Plotting MPG vs. Horsepower:

ggplot(mtcars, aes(x = hp, y = mpg)) +
  geom_point() +
  labs(title = "MPG vs. Horsepower", x = "Horsepower", y = "MPG")
# Out:
# plot without title

# %% [markdown]
# ##Exercises for ggplot2

# %% [markdown]
# **Exercise 1: Scatter Plot Exploration:**
#
# **Dataset:** `mtcars` (built-in)
#
# **Instructions:**
#
# 1. Explore the relationship between "mpg" (miles per gallon) and "hp" (horsepower). Create a scatter plot with labels and a title.
#
# **Solution:**
#
# ```r
# library(datasets)
# data(mtcars)
#
# ggplot(mtcars, aes(x = hp, y = mpg)) +
#   geom_point() +
#   labs(title = "MPG vs. Horsepower", x = "Horsepower", y = "MPG")
# ```
#
# 2. Experiment with different colors for markers using the `color` argument in `aes()`. Try coloring by transmission type ("am").
#
# **Solution:**
#
# ```r
# ggplot(mtcars, aes(x = hp, y = mpg, color = factor(am))) +
#   geom_point() +
#   labs(title = "MPG vs. Horsepower by Transmission", x = "Horsepower", y = "MPG") +
#   scale_color_discrete(labels = c("Automatic", "Manual"))
# ```
#
# 3. Change the marker type to lines using `geom_line()`.
#
# **Solution:**
#
# ```r
# ggplot(mtcars, aes(x = hp, y = mpg, color = factor(am))) +
#   geom_line() +
#   labs(title = "MPG vs. Horsepower by Transmission (Lines)", x = "Horsepower", y = "MPG") +
#   scale_color_discrete(labels = c("Automatic", "Manual"))
# ```
#
# **Exercise 2: Bar Chart Basics:**
#
# **Dataset:** Iris dataset (install `datasets` package)
#
# **Instructions:**
#
# 1. Load the Iris dataset and explore the distribution of "petal length" across different species ("Species"). Create a bar chart with appropriate labels.
#
# **Solution:**
#
# ```r
# library(datasets)
# data(iris)
#
# ggplot(iris, aes(x = Species, y = Petal.Length)) +
#   geom_bar(stat = "identity") +
#   labs(title = "Petal Length Distribution by Species", x = "Species", y = "Petal Length (cm)")
# ```
#
# 2. Customize the bar colors using the `fill` argument in `aes()`. Try coloring by different petal widths ("Petal.Width").
#
# **Solution:**
#
# ```r
# ggplot(iris, aes(x = Species, y = Petal.Length, fill = Petal.Width)) +
#   geom_bar(stat = "identity") +
#   labs(title = "Petal Length Distribution by Species (Colored by Width)", x = "Species", y = "Petal Length (cm)")
# ```
#
# 3. Add horizontal lines indicating the average petal length for each species.
#
# **Solution:**
#
# ```r
# ggplot(iris, aes(x = Species, y = Petal.Length)) +
#   geom_bar(stat = "identity") +
#   labs(title = "Petal Length Distribution with Averages", x = "Species", y = "Petal Length (cm)") +
#   geom_hline(aes(yintercept = mean(Petal.Length)), linetype = "dashed") +
#   facet_wrap(~ Species)
# ```
#
# Remember to explore different options and functionalities within `ggplot2` to enhance your skills!

# %% [markdown]
# ###Key Terminologies in ggplot2

# %% [markdown]
# In ggplot2, `aes` stands for **aesthetic mappings**. It's a crucial function that defines how variables in your data are mapped to visual properties (aesthetics) within your plot.
#
# Here's a breakdown of how `aes` works:
#
# **Syntax:**
#
# ```R
# ggplot(data, aes(x = variable1, y = variable2, ...)) + geom_function()
# ```
#
# - `data`: Your data frame containing relevant variables.
# - `aes()`: The aesthetic mapping function.
# - `x = variable1`, `y = variable2`: These define which variables are mapped to the x and y axes, respectively. You can map additional aesthetics like `color`, `fill`, `size`, `alpha`, etc., within the same `aes()` function.
# - `geom_function()`: This specifies the geometric object (e.g., `geom_point()`, `geom_bar()`, `geom_line()`) you want to use to represent the data points.
#
# **Essentially, `aes` acts as a bridge between your data and the visual elements of your plot.** It tells ggplot2 how to translate numerical values from your variables into visual properties like color, position, size, transparency, and so on.
#
# **Example:**
#
# ```R
# ggplot(iris, aes(x = Sepal.Length, y = Petal.Length, color = Species)) + geom_point()
# ```
#
# Here, `aes` maps the "Sepal.Length" variable to the x-axis, "Petal.Length" to the y-axis, and "Species" to the color aesthetic, resulting in a scatter plot where points are colored based on their species.
#
# Remember, you can experiment with different aesthetic mappings to create diverse and insightful visualizations. For deeper understanding, refer to the ggplot2 documentation and explore various examples online!
